# %% [markdown]
# # Starbucks Capstone Challenge
#
# ### Introduction
#
# This data set contains simulated data that mimics customer behavior on the Starbucks rewards mobile app. Once every few days, Starbucks sends out an offer to users of the mobile app. An offer can be merely an advertisement for a drink or an actual offer such as a discount or BOGO (buy one get one free). Some users might not receive any offer during certain weeks.
#
# Not all users receive the same offer, and that is the challenge to solve with this data set.
#
# Your task is to combine transaction, demographic and offer data to determine which demographic groups respond best to which offer type. This data set is a simplified version of the real Starbucks app because the underlying simulator only has one product whereas Starbucks actually sells dozens of products.
#
# Every offer has a validity period before the offer expires. As an example, a BOGO offer might be valid for only 5 days. You'll see in the data set that informational offers have a validity period even though these ads are merely providing information about a product; for example, if an informational offer has 7 days of validity, you can assume the customer is feeling the influence of the offer for 7 days after receiving the advertisement.
#
# You'll be given transactional data showing user purchases made on the app including the timestamp of purchase and the amount of money spent on a purchase. This transactional data also has a record for each offer that a user receives as well as a record for when a user actually views the offer. There are also records for when a user completes an offer.
#
# Keep in mind as well that someone using the app might make a purchase through the app without having received an offer or seen an offer.
#
# ### Example
#
# To give an example, a user could receive a discount offer buy 10 dollars get 2 off on Monday. The offer is valid for 10 days from receipt. If the customer accumulates at least 10 dollars in purchases during the validity period, the customer completes the offer.
#
# However, there are a few things to watch out for in this data set. Customers do not opt into the offers that they receive; in other words, a user can receive an offer, never actually view the offer, and still complete the offer. For example, a user might receive the "buy 10 dollars get 2 dollars off offer", but the user never opens the offer during the 10 day validity period. The customer spends 15 dollars during those ten days. There will be an offer completion record in the data set; however, the customer was not influenced by the offer because the customer never viewed the offer.
#
# ### Cleaning
#
# This makes data cleaning especially important and tricky.
#
# You'll also want to take into account that some demographic groups will make purchases even if they don't receive an offer. From a business perspective, if a customer is going to make a 10 dollar purchase without an offer anyway, you wouldn't want to send a buy 10 dollars get 2 dollars off offer. You'll want to try to assess what a certain demographic group will buy when not receiving any offers.
#
# ### Final Advice
#
# Because this is a capstone project, you are free to analyze the data any way you see fit. For example, you could build a machine learning model that predicts how much someone will spend based on demographics and offer type. Or you could build a model that predicts whether or not someone will respond to an offer. Or, you don't need to build a machine learning model at all. You could develop a set of heuristics that determine what offer you should send to each customer (i.e., 75 percent of women customers who were 35 years old responded to offer A vs 40 percent from the same demographic to offer B, so send offer A).

# %% [markdown]
# # Data Sets
#
# The data is contained in three files:
#
# * portfolio.json - containing offer ids and meta data about each offer (duration, type, etc.)
# * profile.json - demographic data for each customer
# * transcript.json - records for transactions, offers received, offers viewed, and offers completed
#
# Here is the schema and explanation of each variable in the files:
#
# **portfolio.json**
# * id (string) - offer id
# * offer_type (string) - type of offer ie BOGO, discount, informational
# * difficulty (int) - minimum required spend to complete an offer
# * reward (int) - reward given for completing an offer
# * duration (int) - time for offer to be open, in days
# * channels (list of strings)
#
# **profile.json**
# * age (int) - age of the customer
# * became_member_on (int) - date when customer created an app account
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# **transcript.json**
# * event (str) - record description (ie transaction, offer received, offer viewed, etc.)
# * person (str) - customer id
# * time (int) - time in hours since start of test. The data begins at time t=0
# * value - (dict of strings) - either an offer id or transaction amount depending on the record
#
# **Note:** If you are using the workspace, you will need to go to the terminal and run the command `conda update pandas` before reading in the files. This is because the version of pandas in the workspace cannot read in the transcript.json file correctly, but the newest version of pandas can. You can access the termnal from the orange icon in the top left of this notebook.
#
# You can see how to access the terminal and how the install works using the two images below.  First you need to access the terminal:
#
# <img src="pic1.png"/>
#
# Then you will want to run the above command:
#
# <img src="pic2.png"/>
#
# Finally, when you enter back into the notebook (use the jupyter icon again), you should be able to run the below cell without any errors.

# %%
import pandas as pd
import numpy as np
import math
import json
import os
import matplotlib.pyplot as plt
# % matplotlib inline

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %% [markdown]
# lets have a look at the raw data

# %%
portfolio['duration'] = portfolio['duration']*24 #make duration in hours to match transaction table later
portfolio
# Out:
#    reward                      channels  difficulty  duration     offer_type  \
# 0      10       [email, mobile, social]          10       168           bogo
# 1      10  [web, email, mobile, social]          10       120           bogo
# 2       0          [web, email, mobile]           0        96  informational
# 3       5          [web, email, mobile]           5       168           bogo
# 4       5                  [web, email]          20       240       discount
# 5       3  [web, email, mobile, social]           7       168       discount
# 6       2  [web, email, mobile, social]          10       240       discount
# 7       0       [email, mobile, social]           0        72  informational
# 8       5  [web, email, mobile, social]           5       120           bogo
# 9       2          [web, email, mobile]          10       168       discount
#
#                                  id
# 0  ae264e3637204a6fb9bb56bc8210ddfd
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 2  3f207df678b143eea3cee63160fa8bed
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 6  fafdcd668e3743c1bb461111dcafc2a4
# 7  5a8bc65990b245e5a138643cd4eb9837
# 8  f19421c1d4aa40978ebb69ca19b0e20d
# 9  2906b810c7d4411798c6938adc9daaa5

# %% [markdown]
# first lets create numerical data out of the offer_type, since it is either ```bogo```, ```discount``` or ```informational``` . Lateron we can remove the last column since being dependant of the first two when using the dataframe for training a model.

# %%
# portfolio = pd.concat([portfolio, pd.get_dummies(portfolio.offer_type)[['bogo','discount','informational']]],axis=1)
# portfolio.drop('offer_type',axis=1,inplace=True)
# portfolio

# %% [markdown]
# lets also proceed in the same manner with the ```channels```

# %%
# # find all unique values of chanenls 

# unique_channels = list(set(portfolio.channels.sum())) #what are possible channels
# unique_channels= [str(channel) for channel in unique_channels] #convert to non unicode strings


# # create columns for unique values of channels and do one-hot-encoding - later we might want to reduce it by one dependant column

# for channel in unique_channels:
#     portfolio[channel] = portfolio['channels'].apply(lambda x: 1 if channel in x else 0)
# portfolio.drop('channels',axis=1, inplace=True)

# portfolio

# %%
# portfolio.set_index('id',inplace=True)

# %%
portfolio
# Out:
#    reward                      channels  difficulty  duration     offer_type  \
# 0      10       [email, mobile, social]          10       168           bogo
# 1      10  [web, email, mobile, social]          10       120           bogo
# 2       0          [web, email, mobile]           0        96  informational
# 3       5          [web, email, mobile]           5       168           bogo
# 4       5                  [web, email]          20       240       discount
# 5       3  [web, email, mobile, social]           7       168       discount
# 6       2  [web, email, mobile, social]          10       240       discount
# 7       0       [email, mobile, social]           0        72  informational
# 8       5  [web, email, mobile, social]           5       120           bogo
# 9       2          [web, email, mobile]          10       168       discount
#
#                                  id
# 0  ae264e3637204a6fb9bb56bc8210ddfd
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 2  3f207df678b143eea3cee63160fa8bed
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 6  fafdcd668e3743c1bb461111dcafc2a4
# 7  5a8bc65990b245e5a138643cd4eb9837
# 8  f19421c1d4aa40978ebb69ca19b0e20d
# 9  2906b810c7d4411798c6938adc9daaa5

# %% [markdown]
# Lets proceed with the next dataframe - profile
# here we need to make gender as separate columns and clean regarding age and income

# %%
profile.head(5)
# Out:
#   gender  age                                id  became_member_on    income
# 0   None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2   None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4   None  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN

# %%
profile.id = profile.id.apply(str) #convert to non unicode strings

# %%
len(profile[profile.age==118])
# Out:
# 2175

# %%
profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            14825 non-null  object
#  1   age               17000 non-null  int64
#  2   id                17000 non-null  object
#  3   became_member_on  17000 non-null  int64
#  4   income            14825 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 664.2+ KB

# %% [markdown]
# gender and income seem to have a lot of blank values, this might be worth looking at regarding features. maybe people who do not like to give gender or income have certain tendencies. obviously age==118 correlates with gender=None and Income None

# %% [markdown]
# lets split became_member_on into year,month,day columns

# %%
def int_date_to_YMD(integer_date_YMD):
    date_string = str(integer_date_YMD)
    return date_string[:4], date_string[4:6], date_string[6:]

# %%
profile.describe()
# Out:
#                 age  became_member_on         income
# count  17000.000000      1.700000e+04   14825.000000
# mean      62.531412      2.016703e+07   65404.991568
# std       26.738580      1.167750e+04   21598.299410
# min       18.000000      2.013073e+07   30000.000000
# 25%       45.000000      2.016053e+07   49000.000000
# 50%       58.000000      2.017080e+07   64000.000000
# 75%       73.000000      2.017123e+07   80000.000000
# max      118.000000      2.018073e+07  120000.000000

# %% [markdown]
# maximum and average seem to tend a bit high, something worth looking at in a distribution

# %%
plt.hist(profile.age)
# Out:
# (array([1308., 1438., 2054., 3383., 3257., 2031.,  966.,  361.,   27.,
#         2175.]),
#  array([ 18.,  28.,  38.,  48.,  58.,  68.,  78.,  88.,  98., 108., 118.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# the average of age looks quite high for starbucks customers and the max age is probably outliers which need to be taken care of in either removing or guessing whether they substitute some other value.
# first approach lets remove 118

# %%
profile = profile[profile.age!=118]

# %% [markdown]
# lets convert the male/female/other entries into columns

# %%
profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14825 entries, 1 to 16999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            14825 non-null  object
#  1   age               14825 non-null  int64
#  2   id                14825 non-null  object
#  3   became_member_on  14825 non-null  int64
#  4   income            14825 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 694.9+ KB

# %% [markdown]
# checking for double ids in dataset - obviously none

# %%
profile
# Out:
#       gender  age                                id  became_member_on  \
# 1          F   55  0610b486422d4921ae7d2bf64640c50b          20170715
# 3          F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509
# 5          M   68  e2127556f4f64592b11af22de27a7932          20180426
# 8          M   65  389bc3fa690240e798340f5a15918d5c          20180209
# 12         M   58  2eeac8d8feae4a8cad5a6af0499a211d          20171111
# ...      ...  ...                               ...               ...
# 16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7          20180604
# 16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77          20180713
# 16997      M   49  01d26f638c274aa0b965d24cefe3183f          20170126
# 16998      F   83  9dc1421481194dcd9400aec7c9ae6366          20160307
# 16999      F   62  e4052622e5ba45a8b96b59aba68cf068          20170722
#
#          income
# 1      112000.0
# 3      100000.0
# 5       70000.0
# 8       53000.0
# 12      51000.0
# ...         ...
# 16995   54000.0
# 16996   72000.0
# 16997   73000.0
# 16998   50000.0
# 16999   82000.0
#
# [14825 rows x 5 columns]

# %%
len(profile.id.unique())
# Out:
# 14825

# %%
plt.hist(profile.dropna()['income'])
# Out:
# (array([1731., 1707., 2234., 2210., 2345., 1435., 1215.,  990.,  498.,
#          460.]),
#  array([ 30000.,  39000.,  48000.,  57000.,  66000.,  75000.,  84000.,
#          93000., 102000., 111000., 120000.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# now a look onto transcript

# %%
transcript.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306534 entries, 0 to 306533
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   person  306534 non-null  object
#  1   event   306534 non-null  object
#  2   value   306534 non-null  object
#  3   time    306534 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 9.4+ MB

# %%
transcript.head()
# Out:
#                              person           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
# 2  e2127556f4f64592b11af22de27a7932  offer received
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4  68617ca6246f4fbc85e91a2a49552598  offer received
#
#                                               value  time
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0

# %%
transcript.iloc[24532]
# Out:
# person                     94de646f7b6041228ca7dec82adb97d2
# event                                       offer completed
# value     {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...
# time                                                     30
# Name: 24532, dtype: object

# %%
possible_keys = transcript['value'].apply(lambda x: str(list(x.keys())))
possible_keys.value_counts()
# Out:
# ['amount']                138953
# ['offer id']              134002
# ['offer_id', 'reward']     33579
# Name: value, dtype: int64

# %%
[str(item) for item in list(transcript.event.unique())] #look at the unique non unicode strings
# Out:
# ['offer received', 'offer viewed', 'transaction', 'offer completed']

# %% [markdown]
# create separate columns for offer id, amount and reward

# %%
transcript['offer_id'] = transcript.value.apply(lambda x: list(x.values())[0] if 'offer' in str(list(x.keys())[0]) else None)
transcript['amount'] = transcript.value.apply(lambda x: list(x.values())[0] if (list(x.keys())[0])==u'amount' else None)
transcript['reward'] = transcript.value.apply(lambda x: list(x.values())[1] if len(x.keys())==2 else None)
transcript.drop('value',axis=1,inplace=True)

# %%
limit = 50000000

# %%
views
# Out:
#                                   person         event  time  \
# 12650   389bc3fa690240e798340f5a15918d5c  offer viewed     0
# 12651   d1ede868e29245ea91818a903fec04c6  offer viewed     0
# 12652   102e9454054946fda62242d2e176fdce  offer viewed     0
# 12653   02c083884c7d45b39cc68e1314fec56c  offer viewed     0
# 12655   be8a5d1981a2458d90b255ddc7e0d174  offer viewed     0
# ...                                  ...           ...   ...
# 306441  d56386cf344c4829bbf420d1895dca37  offer viewed   714
# 306450  9b51e8797290403b90d09d864dec4b94  offer viewed   714
# 306483  84fb57a7fe8045a8bf6236738ee73a0f  offer viewed   714
# 306490  abc4359eb34e4e2ca2349da2ddf771b6  offer viewed   714
# 306507  8dda575c2a1d44b9ac8e8b07b93d1f8e  offer viewed   714
#
#                                 offer_id  amount  reward
# 12650   f19421c1d4aa40978ebb69ca19b0e20d     NaN     NaN
# 12651   5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 12652   4d5c57ea9a6940dd891ad53e9dbe8da0     NaN     NaN
# 12653   ae264e3637204a6fb9bb56bc8210ddfd     NaN     NaN
# 12655   5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# ...                                  ...     ...     ...
# 306441  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 306450  3f207df678b143eea3cee63160fa8bed     NaN     NaN
# 306483  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 306490  3f207df678b143eea3cee63160fa8bed     NaN     NaN
# 306507  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
#
# [57725 rows x 6 columns]

# %%
transaction = transcript[transcript.event == 'transaction'][:limit].copy()
trans_fil = transaction.copy()
offer_list = [x[:3] for x in list(portfolio.id)]
offer_list = list(portfolio.id)
transaction[offer_list] = None
#transaction = transaction[transaction['person']=='79d9d4f86aca4bed9290350fb43817c2']
transaction.head()
# Out:
#                                  person        event  time offer_id  amount  \
# 12654  02c083884c7d45b39cc68e1314fec56c  transaction     0     None    0.83
# 12657  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f  transaction     0     None   34.56
# 12659  54890f68699049c2a04d415abc25e717  transaction     0     None   13.23
# 12670  b2f1cd155b864803ad8334cdf13c4bd2  transaction     0     None   19.51
# 12671  fe97aa22dd3e48c8b143116a8403dd52  transaction     0     None   18.97
#
#        reward ae264e3637204a6fb9bb56bc8210ddfd  \
# 12654     NaN                             None
# 12657     NaN                             None
# 12659     NaN                             None
# 12670     NaN                             None
# 12671     NaN                             None
#
#       4d5c57ea9a6940dd891ad53e9dbe8da0 3f207df678b143eea3cee63160fa8bed  \
# 12654                             None                             None
# 12657                             None                             None
# 12659                             None                             None
# 12670                             None                             None
# 12671                             None                             None
#
#       9b98b8c7a33c4b65b9aebfe6a799e6d9 0b1e1539f2cc45b7b9fa7c272da2e1d7  \
# 12654                             None                             None
# 12657                             None                             None
# 12659                             None                             None
# 12670                             None                             None
# 12671                             None                             None
#
#       2298d6c36e964ae4a3e7e9706d1fb8c2 fafdcd668e3743c1bb461111dcafc2a4  \
# 12654                             None                             None
# 12657                             None                             None
# 12659                             None                             None
# 12670                             None                             None
# 12671                             None                             None
#
#       5a8bc65990b245e5a138643cd4eb9837 f19421c1d4aa40978ebb69ca19b0e20d  \
# 12654                             None                             None
# 12657                             None                             None
# 12659                             None                             None
# 12670                             None                             None
# 12671                             None                             None
#
#       2906b810c7d4411798c6938adc9daaa5
# 12654                             None
# 12657                             None
# 12659                             None
# 12670                             None
# 12671                             None

# %%
views = transcript[transcript.event == 'offer viewed'][:limit].copy()

# %%
# %%time
offer_fill_list = []
for offer in offer_list[:]:
    target = []
    for i,row in transaction[:100].iterrows():
        test = list(views[(views['person']==row['person']) & (views['offer_id']==offer)]['time'])
        if len(test) >1:
            print(test)
        target.append([test])
    offer_colum = pd.DataFrame(target)
    offer_fill_list.append(offer_colum)
complete_df = pd.concat(offer_fill_list,axis=1)
        #transaction[offer] = transaction.apply(lambda x:list((views[(views['person']==x['person'])&(views['offer_id']==offer)])['time']))
# Out:
# [18, 552]
# [78, 174, 498]
# [378, 570]
# [420, 522]
# [0, 348]
# [360, 534]
# [336, 588]
# [24, 510]
# [168, 540]
# [168, 522]
# [510, 600]
# [438, 588]
# [198, 504, 624]
# [168, 576]
# [486, 582]
# [174, 510]
# [336, 420]
# [420, 504]
# [462, 504]
# [516, 588]
# [96, 582]
# [60, 444]
# [12, 522]
# [366, 552]
# [0, 168, 504]
# [0, 174]
# [18, 414]
# [336, 714]
# [72, 576]
# [0, 168]
# [342, 408]
# [198, 576]
# [0, 408]
# [204, 576]
# [486, 576]
# [0, 414]
# [408, 546]
# [432, 504]
# [12, 618]
# [336, 462]
# [0, 534]
# [504, 582]
# [210, 528]
# [36, 312]
# Wall time: 11.1 s

# %%
complete_df.columns = offer_list

# %%
complete_df
# Out:
#    ae264e3637204a6fb9bb56bc8210ddfd 4d5c57ea9a6940dd891ad53e9dbe8da0  \
# 0                               [0]                               []
# 1                                []                            [516]
# 2                                []                               []
# 3                             [606]                               []
# 4                                []                               []
# ..                              ...                              ...
# 95                            [216]                       [438, 588]
# 96                               []                            [342]
# 97                               []                               []
# 98                               []                               []
# 99                               []                            [528]
#
#    3f207df678b143eea3cee63160fa8bed 9b98b8c7a33c4b65b9aebfe6a799e6d9  \
# 0                                []                               []
# 1                                []                               []
# 2                                []                               []
# 3                             [198]                               []
# 4                   [198, 504, 624]                               []
# ..                              ...                              ...
# 95                               []                               []
# 96                               []                             [78]
# 97                               []                             [36]
# 98                               []                               []
# 99                               []                               []
#
#    0b1e1539f2cc45b7b9fa7c272da2e1d7 2298d6c36e964ae4a3e7e9706d1fb8c2  \
# 0                                []                               []
# 1                             [462]                            [342]
# 2                                []                            [186]
# 3                                []                            [396]
# 4                                []                               []
# ..                              ...                              ...
# 95                               []                               []
# 96                               []                               []
# 97                               []                               []
# 98                            [516]                               []
# 99                               []                            [606]
#
#    fafdcd668e3743c1bb461111dcafc2a4 5a8bc65990b245e5a138643cd4eb9837  \
# 0                                []                               []
# 1                                []                               []
# 2                                []                            [468]
# 3                             [408]                             [66]
# 4                               [6]                            [420]
# ..                              ...                              ...
# 95                               []                               []
# 96                               []                               []
# 97                               []                               []
# 98                               []                            [582]
# 99                               []                               []
#
#    f19421c1d4aa40978ebb69ca19b0e20d 2906b810c7d4411798c6938adc9daaa5
# 0                                []                               []
# 1                                []                              [0]
# 2                                []                               []
# 3                                []                               []
# 4                                []                               []
# ..                              ...                              ...
# 95                               []                               []
# 96                               []                            [516]
# 97                            [216]                               []
# 98                               []                        [36, 312]
# 99                            [414]                               []
#
# [100 rows x 10 columns]

# %%
pd.DataFrame(target)
# Out:
#        0
# 0    0.0
# 1    NaN
# 2    NaN
# 3  606.0
# 4    NaN
# 5    NaN
# 6    NaN
# 7  702.0
# 8    0.0
# 9    NaN

# %%
target
# Out:
# [[0],
#  [],
#  [],
#  [606],
#  [],
#  [],
#  [],
#  [702],
#  [0],
#  [],
#  [],
#  [516],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [0],
#  [],
#  [],
#  [],
#  [198],
#  [198, 504, 624],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [0],
#  [528],
#  [168],
#  [588],
#  [],
#  [],
#  [462],
#  [],
#  [],
#  [],
#  [462, 504],
#  [],
#  [558],
#  [],
#  [],
#  [],
#  [342],
#  [186],
#  [396],
#  [],
#  [],
#  [354],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [408],
#  [6],
#  [],
#  [582],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [468],
#  [66],
#  [420],
#  [204, 576],
#  [],
#  [150],
#  [],
#  [438],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [420],
#  [336],
#  [],
#  [],
#  [],
#  [0],
#  [],
#  [],
#  [],
#  [336],
#  [],
#  [414],
#  [],
#  [396]]

# %%
len(transaction[transaction['test'].isnull()])
# Out:
# 138953

# %%
len(transaction)
# Out:
# 138953

# %%
list(views[(views['person']=='79d9d4f86aca4bed9290350fb43817c2') & (views['offer_id']=='2298d6c36e964ae4a3e7e9706d1fb8c2')]['time'])
# Out:
# [336]

# %%
transaction.groupby('person').count().sort_values('event',ascending=False)
# Out:
#                                   event  time  offer_id  amount  reward  \
# person
# 79d9d4f86aca4bed9290350fb43817c2     36    36         0      36       0
# 8dbfa485249f409aa223a2130f40634a     36    36         0      36       0
# 94de646f7b6041228ca7dec82adb97d2     35    35         0      35       0
# b1f4ece7d49342628a9ed77aee2cde58     32    32         0      32       0
# 5e60c6aa3b834e44b822ea43a3efea26     32    32         0      32       0
# ...                                 ...   ...       ...     ...     ...
# 3bc7544c64164046a017fa6c20d65a6c      1     1         0       1       0
# 3be15bacb2064198874cbf898ca5cf82      1     1         0       1       0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b      1     1         0       1       0
# b8725275fd214d7ab37d31d365866d54      1     1         0       1       0
# 7fc0bf97fd3e4153b7a4022d7266e9f7      1     1         0       1       0
#
#                                   ae264e3637204a6fb9bb56bc8210ddfd  \
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
#                                   4d5c57ea9a6940dd891ad53e9dbe8da0  \
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
#                                   3f207df678b143eea3cee63160fa8bed  \
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
#                                   9b98b8c7a33c4b65b9aebfe6a799e6d9  \
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
#                                   0b1e1539f2cc45b7b9fa7c272da2e1d7  \
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
#                                   2298d6c36e964ae4a3e7e9706d1fb8c2  \
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
#                                   fafdcd668e3743c1bb461111dcafc2a4  \
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
#                                   5a8bc65990b245e5a138643cd4eb9837  \
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
#                                   f19421c1d4aa40978ebb69ca19b0e20d  \
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
#                                   2906b810c7d4411798c6938adc9daaa5
# person
# 79d9d4f86aca4bed9290350fb43817c2                                 0
# 8dbfa485249f409aa223a2130f40634a                                 0
# 94de646f7b6041228ca7dec82adb97d2                                 0
# b1f4ece7d49342628a9ed77aee2cde58                                 0
# 5e60c6aa3b834e44b822ea43a3efea26                                 0
# ...                                                            ...
# 3bc7544c64164046a017fa6c20d65a6c                                 0
# 3be15bacb2064198874cbf898ca5cf82                                 0
# 3bfb6c8c7d8d42e68c9f66d296a1c96b                                 0
# b8725275fd214d7ab37d31d365866d54                                 0
# 7fc0bf97fd3e4153b7a4022d7266e9f7                                 0
#
# [16578 rows x 15 columns]

# %%
views[views['person']=='79d9d4f86aca4bed9290350fb43817c2']
# Out:
#                                   person         event  time  \
# 23458   79d9d4f86aca4bed9290350fb43817c2  offer viewed    24
# 125723  79d9d4f86aca4bed9290350fb43817c2  offer viewed   336
# 264184  79d9d4f86aca4bed9290350fb43817c2  offer viewed   582
#
#                                 offer_id  amount  reward
# 23458   fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 125723  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN     NaN
# 264184  3f207df678b143eea3cee63160fa8bed     NaN     NaN

# %%
transcript.head(10)
# Out:
#                              person           event  time  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received     0
# 1  a03223e636434f42ac4c3df47e8bac43  offer received     0
# 2  e2127556f4f64592b11af22de27a7932  offer received     0
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received     0
# 4  68617ca6246f4fbc85e91a2a49552598  offer received     0
# 5  389bc3fa690240e798340f5a15918d5c  offer received     0
# 6  c4863c7985cf408faee930f111475da3  offer received     0
# 7  2eeac8d8feae4a8cad5a6af0499a211d  offer received     0
# 8  aa4862eba776480b8bb9c68455b8c2e1  offer received     0
# 9  31dda685af34476cad5bc968bdb01c53  offer received     0
#
#                            offer_id  amount  reward
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 2  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 3  fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN     NaN
# 5  f19421c1d4aa40978ebb69ca19b0e20d     NaN     NaN
# 6  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN     NaN
# 7  3f207df678b143eea3cee63160fa8bed     NaN     NaN
# 8  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 9  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN

# %% [markdown]
# check, what are customers with a high order behaviour

# %%
multi_order = transcript.groupby('person').count()
multi_order.sort_values('event',ascending=False,inplace=True)
multi_order.head()
# Out:
#                                   event  time  offer_id  amount  reward
# person
# 94de646f7b6041228ca7dec82adb97d2     51    51        16      35       5
# 8dbfa485249f409aa223a2130f40634a     49    49        13      36       3
# 5e60c6aa3b834e44b822ea43a3efea26     48    48        16      32       5
# d0a80415b84c4df4908b8403b19765e3     48    48        18      30       6
# 79d9d4f86aca4bed9290350fb43817c2     48    48        12      36       4

# %% [markdown]
# chose a sample customer for looking into one example behaviour

# %%
example_customer = multi_order.index[0]

# %%
#transcript[transcript['person']==example_customer].to_excel('sample_customer.xlsx')

# %%
#transcript[(transcript['amount']>1) | (transcript['reward']>1)].head(7)

# %% [markdown]
# create a temporary dataframe containing all times of offer received and offer viewed. this will be usefull for feature engineering. Due to the merge there will be data in the result where offer viewed will be before offer received. these must be removed. once this is done removing duplicate values in the time received column will make sure only adjacent events of offer received and offer viewed are counted into one event

# %%
df_temp_view = pd.merge(transcript[transcript['event'] == 'offer received'][['person', 'offer_id', 'time']],
                 transcript[transcript['event'] == 'offer viewed'][['person', 'offer_id', 'time']],
                 on=['person', 'offer_id'], how='left', suffixes=['_received', '_viewed'])

#keep entries that are equal meaning the customer checked the offer quite quickly
df_temp_view = df_temp_view[~(df_temp_view['time_viewed'] < df_temp_view['time_received'])] 

# now that all values are removed where time viewed is smaller than time received duplicates can be removed
df_temp_view.drop_duplicates(['person','offer_id','time_received'],keep='first',inplace=True)

# this handles the edgecase where a new offer is received and viewed and an older offer of the same type has never been viewed
# nevertheless it can still happen that an offer is viewed very long after having it received
df_temp_view.drop_duplicates(['person','offer_id','time_viewed'],keep='last',inplace=True)

# %%
df_temp_view[df_temp_view['time_viewed']<df_temp_view['time_received']]
# Out:
# Empty DataFrame
# Columns: [person, offer_id, time_received, time_viewed]
# Index: []

# %% [markdown]
# <- no inconsistancies

# %% [markdown]
# the same approach as before is chosen for creating a dataset considerung the time of offer completed and the reward information

# %%
df_temp_completed =  pd.merge(transcript[transcript['event'] == 'offer received'][['person', 'offer_id', 'time']],
                 transcript[transcript['event'] == 'offer completed'][['person', 'offer_id', 'time','reward']],
                 on=['person', 'offer_id'], how='left', suffixes=['_received', '_completed'])


df_temp_completed = df_temp_completed[~(df_temp_completed['time_completed'] < df_temp_completed['time_received'])] #keep entries that are equal meaning the customer checked the offer quite quickly
df_temp_completed.drop_duplicates(['person','offer_id','time_received'],keep='first',inplace=True) # now that all values are removed where time viewed is smaller than time received duplicates can be removed

# df_sample = df_temp_completed[df_temp_completed['person']==example_customer].copy()
# df_sample
df_temp_completed.drop_duplicates(['person','offer_id','time_completed'],keep='last',inplace=True)

# %%
df_temp_completed[df_temp_completed['time_completed']<df_temp_completed['time_received']]
# Out:
# Empty DataFrame
# Columns: [person, offer_id, time_received, time_completed, reward]
# Index: []

# %% [markdown]
# <- no inconsistancies
# now the newly created temporary frames will be merged

# %%
customer_offers = pd.merge(df_temp_view,
                           df_temp_completed,
                          on=['person','offer_id','time_received'],
                          how='left')

# %% [markdown]
# last check needs to be, whether there are data which have a time completed being smaller time viewed. as expected there are data where the customer completes the offer but has never viewed it.

# %%
# negatives = customer_offers[customer_offers['time completed']<customer_offers['time viewed']].copy()
# negatives.head()

# %%
customer_offers['delta_viewed_received'] = customer_offers['time_viewed'] - customer_offers['time_received']
customer_offers['delta_completed_received'] = customer_offers['time_completed'] - customer_offers['time_received']
customer_offers['delta_completed_viewed'] = customer_offers['time_completed'] - customer_offers['time_viewed']

# %%
len(customer_offers)
# Out:
# 71878

# %% [markdown]
# to later also use the informational offers as possible features we assume, as stated in the task, that a customer is influenced by the information for the duration time given in the portfolio dataset for each informational offer after he or she has *received* the offer. i add that he can only be influenced if he saw the offer which leads to the following processing

# %%
information_offers = [str(x) for x in list(portfolio[portfolio['offer_type']=='informational']['id'])]
information_offers
for offer_id in information_offers: #two informational offers are present in portfolio
    info_completion_time = portfolio[portfolio['id']==offer_id]['duration'] #each info offer has a duration
    #info_completion_time = 48 #setting completion time manually in hrs
    delta_time_complete = info_completion_time.iloc[0]
    
    # time completed should be the time after receiving the info offer
    customer_offers.loc[(customer_offers['offer_id']==offer_id) & ~(customer_offers['time_viewed'].isnull()),'time_completed']  = customer_offers['time_received']+delta_time_complete
    
    # now if the time viewed is larger than time completed the customer cannot have been influenced by the info offer thus will be have a time completed set to nan
    customer_offers.loc[(customer_offers['offer_id']==offer_id) & (customer_offers['time_completed'] < customer_offers['time_viewed']),'time_completed'] = None   
    
    #the reward is generally 0 on info offers but should be nan if there was not even a view or a view after the validity 
    customer_offers.loc[customer_offers['offer_id']==offer_id,'reward'] = 0 * customer_offers['time_completed'] #keeping nan as nan and others to 0

# %% [markdown]
# unfortunately there is no information in the transcript table about when an informational offer is completed. for a compensation we will proceed as follows.
# - so far for all other offers there is a **offer received**, **offer viewed** and **offer completed** entry. we will enrich the table by a calculated completion row for valid data points of informational offer completed
# - first we sort the data frame for person and continue to work on a copy - adding some helper columns as offer_type
# - excluding the rows we dont need for computation: only keep transactions and informational offers viewed
# - by shifting event and person columns we make sure we only process rows that belong together. we compare the shifted rows with the original entries in a row and decide whether a record is to be kept or not
# - by logical combination of the keep_* columns we have created a criteria a data frame that holds an informational offer followed by the nearest transaction
# - we replace **transaction** in the event column by **offer_id** from the previous row to match the row entries from the original transcript table
# - now we will check if the time of the nearest transaction is still within the duration period allowed for the informational offer
# - setting **amount** and **offer_type** colmn to **np.nan** and **informational** resectively to match the original transcript table format
# - reducint the amount of columns to the ones necessary

# %%
transcript.head()
# Out:
#                                   person           event  time  \
# 55972   0009655768c64bdeb2e877511632db8f  offer received   168
# 77705   0009655768c64bdeb2e877511632db8f    offer viewed   192
# 89291   0009655768c64bdeb2e877511632db8f     transaction   228
# 113605  0009655768c64bdeb2e877511632db8f  offer received   336
# 139992  0009655768c64bdeb2e877511632db8f    offer viewed   372
#
#                                 offer_id  amount  reward
# 55972   5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 77705   5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 89291                               None   22.16     NaN
# 113605  3f207df678b143eea3cee63160fa8bed     NaN     NaN
# 139992  3f207df678b143eea3cee63160fa8bed     NaN     NaN

# %%
transcript.sort_values(['person','time'],inplace=True)
trans = transcript.copy()
trans['offer_type'] = trans['offer_id'].apply(lambda x:look_up_offer_type[x])
trans = trans[(trans['offer_type']=='informational')|(trans['offer_type'].isnull())].copy()
trans = trans[(trans['event']=='offer viewed')|(trans['event']=='transaction')]

trans['keep_trans'] = (trans['event']=='transaction') & (trans['event'].shift(1)=='offer viewed') & (trans['person']==trans['person'].shift(1))
trans['keep_offer'] = (trans['event']=='offer viewed') & (trans['event'].shift(-1)=='transaction') & (trans['person']==trans['person'].shift(-1))
# trans['person_shift'] = trans['person'].shift(-1)
trans = trans[trans['keep_trans'] | trans['keep_offer']]

trans.loc[trans['offer_id'].isnull(),'offer_id'] = trans['offer_id'].shift(1)

# %% [markdown]
# check necessary if time for transaction is within duration

# %%
lookup_duration = lookup_dictionary(portfolio,'id','duration')
trans['duration'] = trans['offer_id'].apply(lambda x: lookup_duration[x])
trans['time_pot_complete'] = trans['time'].shift(-1)
trans['within_time'] = (trans['time_pot_complete'] - trans['time'])<=trans['duration']
trans = trans[(trans['event']=='transaction') & (trans['within_time']==True)].copy()
trans['amount'] = np.nan
trans['offer_type'] = 'informational'

# %%
transcript.head(2)
# Out:
#                                  person           event  time  \
# 55972  0009655768c64bdeb2e877511632db8f  offer received   168
# 77705  0009655768c64bdeb2e877511632db8f    offer viewed   192
#
#                                offer_id  amount  reward
# 55972  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 77705  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN

# %%
trans
# Out:
#                                   person        event  time  \
# 168412  0009655768c64bdeb2e877511632db8f  transaction   414
# 302122  0020c2b971eb4e9188eac86d93036a77  transaction   696
# 175779  0020ccbbb6d84e358d3414a3ff76cffd  transaction   426
# 144667  003d66b6608740288d6cc97a6903f4f0  transaction   384
# 240731  0056df74b63b4298809f0b375a304cf4  transaction   558
# ...                                  ...          ...   ...
# 282949  ffc60f10c2444740bc2049712bbffe17  transaction   624
# 173803  ffeaa02452ef451082a0361c3ca62ef5  transaction   420
# 221740  ffecb1f8543f4bf7bade023de366d6bf  transaction   510
# 294474  fff0f0aac6c547b9b263080f09a5586a  transaction   660
# 233588  fff3ba4757bd42088c044ca26d73817a  transaction   540
#
#                                 offer_id  amount  reward     offer_type  \
# 168412  3f207df678b143eea3cee63160fa8bed     NaN     NaN  informational
# 302122  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 175779  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 144667  3f207df678b143eea3cee63160fa8bed     NaN     NaN  informational
# 240731  3f207df678b143eea3cee63160fa8bed     NaN     NaN  informational
# ...                                  ...     ...     ...            ...
# 282949  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 173803  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 221740  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 294474  3f207df678b143eea3cee63160fa8bed     NaN     NaN  informational
# 233588  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
#
#         keep_trans  keep_offer  duration  time_pot_complete  within_time
# 168412        True       False        96                6.0         True
# 302122        True       False        72              408.0         True
# 175779        True       False        72               36.0         True
# 144667        True       False        96               36.0         True
# 240731        True       False        96               18.0         True
# ...            ...         ...       ...                ...          ...
# 282949        True       False        72              198.0         True
# 173803        True       False        72               78.0         True
# 221740        True       False        72              288.0         True
# 294474        True       False        96              540.0         True
# 233588        True       False        72              168.0         True
#
# [6316 rows x 12 columns]

# %%
inf_transaction_to_offer_completed = trans[['person','event','time','offer_id','amount','reward','offer_type']]

# %%
inf_transaction_to_offer_completed
# Out:
#                                   person        event  time  \
# 168412  0009655768c64bdeb2e877511632db8f  transaction   414
# 302122  0020c2b971eb4e9188eac86d93036a77  transaction   696
# 175779  0020ccbbb6d84e358d3414a3ff76cffd  transaction   426
# 144667  003d66b6608740288d6cc97a6903f4f0  transaction   384
# 240731  0056df74b63b4298809f0b375a304cf4  transaction   558
# ...                                  ...          ...   ...
# 282949  ffc60f10c2444740bc2049712bbffe17  transaction   624
# 173803  ffeaa02452ef451082a0361c3ca62ef5  transaction   420
# 221740  ffecb1f8543f4bf7bade023de366d6bf  transaction   510
# 294474  fff0f0aac6c547b9b263080f09a5586a  transaction   660
# 233588  fff3ba4757bd42088c044ca26d73817a  transaction   540
#
#                                 offer_id  amount  reward     offer_type
# 168412  3f207df678b143eea3cee63160fa8bed     NaN     NaN  informational
# 302122  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 175779  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 144667  3f207df678b143eea3cee63160fa8bed     NaN     NaN  informational
# 240731  3f207df678b143eea3cee63160fa8bed     NaN     NaN  informational
# ...                                  ...     ...     ...            ...
# 282949  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 173803  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 221740  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
# 294474  3f207df678b143eea3cee63160fa8bed     NaN     NaN  informational
# 233588  5a8bc65990b245e5a138643cd4eb9837     NaN     NaN  informational
#
# [6316 rows x 7 columns]

# %% [markdown]
# looking into one specific customer the values seem plausible. one can see interesting cases
# - first row shows the infomation offer
# - second row has a regular offer with reward
# - third row shows the case where the offer was read after completion only

# %%
sample2 = customer_offers[customer_offers['person']=='a5a6ef2b78a04ddc9f374dd7c7f60bff'].copy()
sample2
# Out:
#                                  person                          offer_id  \
# 43     a5a6ef2b78a04ddc9f374dd7c7f60bff  5a8bc65990b245e5a138643cd4eb9837
# 35449  a5a6ef2b78a04ddc9f374dd7c7f60bff  2906b810c7d4411798c6938adc9daaa5
# 47506  a5a6ef2b78a04ddc9f374dd7c7f60bff  9b98b8c7a33c4b65b9aebfe6a799e6d9
#
#        time_received  time_viewed  time_completed  reward  \
# 43                 0          6.0            72.0     0.0
# 35449            408        414.0           420.0     2.0
# 47506            504        534.0           510.0     5.0
#
#        delta_viewed_received  delta_completed_received  delta_completed_viewed
# 43                       6.0                       NaN                     NaN
# 35449                    6.0                      12.0                     6.0
# 47506                   30.0                       6.0                   -24.0

# %%
sample = customer_offers[customer_offers['person']==example_customer].copy()
sample
# Out:
#                                  person                          offer_id  \
# 2144   94de646f7b6041228ca7dec82adb97d2  f19421c1d4aa40978ebb69ca19b0e20d
# 13985  94de646f7b6041228ca7dec82adb97d2  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 25817  94de646f7b6041228ca7dec82adb97d2  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 37558  94de646f7b6041228ca7dec82adb97d2  fafdcd668e3743c1bb461111dcafc2a4
# 49618  94de646f7b6041228ca7dec82adb97d2  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 61668  94de646f7b6041228ca7dec82adb97d2  4d5c57ea9a6940dd891ad53e9dbe8da0
#
#        time_received  time_viewed  time_completed  reward  \
# 2144               0          6.0            30.0     5.0
# 13985            168        186.0           270.0     5.0
# 25817            336          NaN           492.0     5.0
# 37558            408        408.0           420.0     2.0
# 49618            504        516.0           606.0     5.0
# 61668            576        624.0             NaN     NaN
#
#        delta_viewed_received  delta_completed_received  delta_completed_viewed
# 2144                     6.0                      30.0                    24.0
# 13985                   18.0                     102.0                    84.0
# 25817                    NaN                     156.0                     NaN
# 37558                    0.0                      12.0                    12.0
# 49618                   12.0                     102.0                    90.0
# 61668                   48.0                       NaN                     NaN

# %% [markdown]
# following data frame ```customer_offers``` represents how much time a person took to view or complete offers. if similar offers were sent to the same person it is the sum of times spent. for this we pivot the table for person in rows and offers in columns

# %%
customer_offers[customer_offers['person']=='0cc6e8553c844c02ab525bc466aa569b']
# Out:
#                                  person                          offer_id  \
# 6340   0cc6e8553c844c02ab525bc466aa569b  f19421c1d4aa40978ebb69ca19b0e20d
# 18214  0cc6e8553c844c02ab525bc466aa569b  2298d6c36e964ae4a3e7e9706d1fb8c2
# 29937  0cc6e8553c844c02ab525bc466aa569b  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 41831  0cc6e8553c844c02ab525bc466aa569b  5a8bc65990b245e5a138643cd4eb9837
# 53834  0cc6e8553c844c02ab525bc466aa569b  f19421c1d4aa40978ebb69ca19b0e20d
# 66045  0cc6e8553c844c02ab525bc466aa569b  0b1e1539f2cc45b7b9fa7c272da2e1d7
#
#        time_received  time_viewed  time_completed  reward  \
# 6340               0        108.0             NaN     NaN
# 18214            168        174.0           252.0     3.0
# 29937            336        336.0           522.0     5.0
# 41831            408          NaN             NaN     NaN
# 53834            504        504.0           522.0     5.0
# 66045            576        594.0           630.0     5.0
#
#        delta_viewed_received  delta_completed_received  delta_completed_viewed
# 6340                   108.0                       NaN                     NaN
# 18214                    6.0                      84.0                    78.0
# 29937                    0.0                     186.0                   186.0
# 41831                    NaN                       NaN                     NaN
# 53834                    0.0                      18.0                    18.0
# 66045                   18.0                      54.0                    36.0

# %%
offer_times_pivot = pd.pivot_table(customer_offers, index=['person'], columns=['offer_id'], aggfunc='mean')
offer_times_pivot.columns = offer_times_pivot.columns.swaplevel(0,1)
offer_times_pivot.sort_index(level=0,axis=1,inplace=True)
#customer_offers_pivot=customer_offers_pivot.droplevel(0,axis=1)
offer_times_pivot.head()
# Out:
# offer_id                         0b1e1539f2cc45b7b9fa7c272da2e1d7  \
#                                          delta_completed_received
# person
# 0009655768c64bdeb2e877511632db8f                              NaN
# 00116118485d4dfda04fdbaba9a87b5c                              NaN
# 0011e0d4e6b944f998e987f904e8c1e5                            168.0
# 0020c2b971eb4e9188eac86d93036a77                              NaN
# 0020ccbbb6d84e358d3414a3ff76cffd                              NaN
#
# offer_id                                                                       \
#                                  delta_completed_viewed delta_viewed_received
# person
# 0009655768c64bdeb2e877511632db8f                    NaN                   NaN
# 00116118485d4dfda04fdbaba9a87b5c                    NaN                   NaN
# 0011e0d4e6b944f998e987f904e8c1e5                  144.0                  24.0
# 0020c2b971eb4e9188eac86d93036a77                    NaN                   NaN
# 0020ccbbb6d84e358d3414a3ff76cffd                    NaN                   NaN
#
# offer_id                                                              \
#                                  reward time_completed time_received
# person
# 0009655768c64bdeb2e877511632db8f    NaN            NaN           NaN
# 00116118485d4dfda04fdbaba9a87b5c    NaN            NaN           NaN
# 0011e0d4e6b944f998e987f904e8c1e5    5.0          576.0         408.0
# 0020c2b971eb4e9188eac86d93036a77    NaN            NaN           NaN
# 0020ccbbb6d84e358d3414a3ff76cffd    NaN            NaN           NaN
#
# offer_id                                     2298d6c36e964ae4a3e7e9706d1fb8c2  \
#                                  time_viewed         delta_completed_received
# person
# 0009655768c64bdeb2e877511632db8f         NaN                              NaN
# 00116118485d4dfda04fdbaba9a87b5c         NaN                              NaN
# 0011e0d4e6b944f998e987f904e8c1e5       432.0                             84.0
# 0020c2b971eb4e9188eac86d93036a77         NaN                              NaN
# 0020ccbbb6d84e358d3414a3ff76cffd         NaN                             54.0
#
# offer_id                                                                       \
#                                  delta_completed_viewed delta_viewed_received
# person
# 0009655768c64bdeb2e877511632db8f                    NaN                   NaN
# 00116118485d4dfda04fdbaba9a87b5c                    NaN                   NaN
# 0011e0d4e6b944f998e987f904e8c1e5                   66.0                  18.0
# 0020c2b971eb4e9188eac86d93036a77                    NaN                   NaN
# 0020ccbbb6d84e358d3414a3ff76cffd                   54.0                   0.0
#
# offer_id                          ... f19421c1d4aa40978ebb69ca19b0e20d  \
#                                   ...                   time_completed
# person                            ...
# 0009655768c64bdeb2e877511632db8f  ...                            414.0
# 00116118485d4dfda04fdbaba9a87b5c  ...                              NaN
# 0011e0d4e6b944f998e987f904e8c1e5  ...                              NaN
# 0020c2b971eb4e9188eac86d93036a77  ...                              NaN
# 0020ccbbb6d84e358d3414a3ff76cffd  ...                            378.0
#
# offer_id                                                    \
#                                  time_received time_viewed
# person
# 0009655768c64bdeb2e877511632db8f         408.0       456.0
# 00116118485d4dfda04fdbaba9a87b5c         372.0       423.0
# 0011e0d4e6b944f998e987f904e8c1e5           NaN         NaN
# 0020c2b971eb4e9188eac86d93036a77           NaN         NaN
# 0020ccbbb6d84e358d3414a3ff76cffd         336.0       348.0
#
# offer_id                         fafdcd668e3743c1bb461111dcafc2a4  \
#                                          delta_completed_received
# person
# 0009655768c64bdeb2e877511632db8f                             24.0
# 00116118485d4dfda04fdbaba9a87b5c                              NaN
# 0011e0d4e6b944f998e987f904e8c1e5                              NaN
# 0020c2b971eb4e9188eac86d93036a77                             54.0
# 0020ccbbb6d84e358d3414a3ff76cffd                              NaN
#
# offer_id                                                                       \
#                                  delta_completed_viewed delta_viewed_received
# person
# 0009655768c64bdeb2e877511632db8f                  -12.0                  36.0
# 00116118485d4dfda04fdbaba9a87b5c                    NaN                   NaN
# 0011e0d4e6b944f998e987f904e8c1e5                    NaN                   NaN
# 0020c2b971eb4e9188eac86d93036a77                   42.0                  12.0
# 0020ccbbb6d84e358d3414a3ff76cffd                    NaN                   NaN
#
# offer_id                                                              \
#                                  reward time_completed time_received
# person
# 0009655768c64bdeb2e877511632db8f    2.0          528.0         504.0
# 00116118485d4dfda04fdbaba9a87b5c    NaN            NaN           NaN
# 0011e0d4e6b944f998e987f904e8c1e5    NaN            NaN           NaN
# 0020c2b971eb4e9188eac86d93036a77    2.0           54.0           0.0
# 0020ccbbb6d84e358d3414a3ff76cffd    NaN            NaN           NaN
#
# offer_id
#                                  time_viewed
# person
# 0009655768c64bdeb2e877511632db8f       540.0
# 00116118485d4dfda04fdbaba9a87b5c         NaN
# 0011e0d4e6b944f998e987f904e8c1e5         NaN
# 0020c2b971eb4e9188eac86d93036a77        12.0
# 0020ccbbb6d84e358d3414a3ff76cffd         NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# one more feature should be, how much money a person spent after he or she saw the offer until completing the offer

# %% [markdown]
# for a simplified feature extraction lets create a row indicating if it was an informational offer or real offer having a reward

# %%
portfolio
# Out:
#    reward                      channels  difficulty  duration     offer_type  \
# 0      10       [email, mobile, social]          10       168           bogo
# 1      10  [web, email, mobile, social]          10       120           bogo
# 2       0          [web, email, mobile]           0        96  informational
# 3       5          [web, email, mobile]           5       168           bogo
# 4       5                  [web, email]          20       240       discount
# 5       3  [web, email, mobile, social]           7       168       discount
# 6       2  [web, email, mobile, social]          10       240       discount
# 7       0       [email, mobile, social]           0        72  informational
# 8       5  [web, email, mobile, social]           5       120           bogo
# 9       2          [web, email, mobile]          10       168       discount
#
#                                  id
# 0  ae264e3637204a6fb9bb56bc8210ddfd
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 2  3f207df678b143eea3cee63160fa8bed
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 6  fafdcd668e3743c1bb461111dcafc2a4
# 7  5a8bc65990b245e5a138643cd4eb9837
# 8  f19421c1d4aa40978ebb69ca19b0e20d
# 9  2906b810c7d4411798c6938adc9daaa5

# %%
# def offer_dictionary(look_up_df):
#     temp_df = look_up_df.copy()
#     temp_df['offer_type'] = temp_df['difficulty'].apply(lambda x: 1 if x >0 else 0)
#     return dict(zip(temp_df['id'],temp_df['offer_type']))

def lookup_dictionary(look_up_df,search, result):
    temp_df = look_up_df.copy()
    dic= dict(zip(temp_df[search],temp_df[result]))
    dic[None] = None
    return dic

# %%
#customer_offers['rewarded offer'] = customer_offers['reward'].apply(lambda x: 1 if x>0 else (0 if x==0 else None))
look_up_offer_type = lookup_dictionary(portfolio,'id','offer_type' )
customer_offers['offer_type'] = customer_offers['offer_id'].apply(lambda x: look_up_offer_type[x])

# %% [markdown]
# now we can create a data frame with person in rows and their offer counts in columns. after pivoting this data frame we will be able to do peform feature extraction

# %%
customer_offers.head()
# Out:
#                              person                          offer_id  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 1  a03223e636434f42ac4c3df47e8bac43  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 2  e2127556f4f64592b11af22de27a7932  2906b810c7d4411798c6938adc9daaa5
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  fafdcd668e3743c1bb461111dcafc2a4
# 4  68617ca6246f4fbc85e91a2a49552598  4d5c57ea9a6940dd891ad53e9dbe8da0
#
#    time_received  time_viewed  time_completed  reward  delta_viewed_received  \
# 0              0          6.0           132.0     5.0                    6.0
# 1              0          6.0             NaN     NaN                    6.0
# 2              0         18.0             NaN     NaN                   18.0
# 3              0         12.0             NaN     NaN                   12.0
# 4              0         84.0             NaN     NaN                   84.0
#
#    delta_completed_received  delta_completed_viewed offer_type
# 0                     132.0                   126.0       bogo
# 1                       NaN                     NaN   discount
# 2                       NaN                     NaN   discount
# 3                       NaN                     NaN   discount
# 4                       NaN                     NaN       bogo

# %%
offer_counts = customer_offers.groupby(['person','offer_type']).agg({'time_received':'count',
                             'time_viewed':'count',
                              'time_completed':'count',
                             'reward':'sum'}).rename(columns={'time_received':'count_received',
                                                              'time_viewed':'count_viewed',
                                                              'time_completed':'count_completed',
                                                              'reward':'sum_reward'})
offer_counts_pivot = pd.pivot_table(offer_counts,index='person', columns='offer_type',values=['count_received','count_viewed','count_completed','sum_reward'])
offer_counts_pivot.columns = offer_counts_pivot.columns.swaplevel(0,1)
offer_counts_pivot.sort_index(level=0,axis=1,inplace=True)
offer_counts_pivot.fillna(value=0,inplace=True)
offer_counts_pivot.columns.set_levels(['bogo','discount','informational'],level=0,inplace=True)
offer_counts_pivot.columns = ['%s%s' % (a, '_%s' % b if b else '') for a, b in offer_counts_pivot.columns]
offer_counts_pivot
# Out:
#                                   bogo_count_completed  bogo_count_received  \
# person
# 0009655768c64bdeb2e877511632db8f                   1.0                  1.0
# 00116118485d4dfda04fdbaba9a87b5c                   0.0                  2.0
# 0011e0d4e6b944f998e987f904e8c1e5                   1.0                  1.0
# 0020c2b971eb4e9188eac86d93036a77                   1.0                  2.0
# 0020ccbbb6d84e358d3414a3ff76cffd                   2.0                  2.0
# ...                                                ...                  ...
# fff3ba4757bd42088c044ca26d73817a                   1.0                  1.0
# fff7576017104bcc8677a8d63322b5e1                   1.0                  3.0
# fff8957ea8b240a6b5e634b6ee8eafcf                   0.0                  1.0
# fffad4f4828548d1b5583907f2e9906b                   3.0                  3.0
# ffff82501cea40309d5fdd7edcca4a07                   1.0                  1.0
#
#                                   bogo_count_viewed  bogo_sum_reward  \
# person
# 0009655768c64bdeb2e877511632db8f                1.0              5.0
# 00116118485d4dfda04fdbaba9a87b5c                2.0              0.0
# 0011e0d4e6b944f998e987f904e8c1e5                1.0              5.0
# 0020c2b971eb4e9188eac86d93036a77                1.0             10.0
# 0020ccbbb6d84e358d3414a3ff76cffd                2.0             10.0
# ...                                             ...              ...
# fff3ba4757bd42088c044ca26d73817a                1.0              5.0
# fff7576017104bcc8677a8d63322b5e1                2.0              5.0
# fff8957ea8b240a6b5e634b6ee8eafcf                1.0              0.0
# fffad4f4828548d1b5583907f2e9906b                3.0             15.0
# ffff82501cea40309d5fdd7edcca4a07                1.0              5.0
#
#                                   discount_count_completed  \
# person
# 0009655768c64bdeb2e877511632db8f                       2.0
# 00116118485d4dfda04fdbaba9a87b5c                       0.0
# 0011e0d4e6b944f998e987f904e8c1e5                       2.0
# 0020c2b971eb4e9188eac86d93036a77                       1.0
# 0020ccbbb6d84e358d3414a3ff76cffd                       1.0
# ...                                                    ...
# fff3ba4757bd42088c044ca26d73817a                       1.0
# fff7576017104bcc8677a8d63322b5e1                       2.0
# fff8957ea8b240a6b5e634b6ee8eafcf                       0.0
# fffad4f4828548d1b5583907f2e9906b                       0.0
# ffff82501cea40309d5fdd7edcca4a07                       5.0
#
#                                   discount_count_received  \
# person
# 0009655768c64bdeb2e877511632db8f                      2.0
# 00116118485d4dfda04fdbaba9a87b5c                      0.0
# 0011e0d4e6b944f998e987f904e8c1e5                      2.0
# 0020c2b971eb4e9188eac86d93036a77                      1.0
# 0020ccbbb6d84e358d3414a3ff76cffd                      1.0
# ...                                                   ...
# fff3ba4757bd42088c044ca26d73817a                      2.0
# fff7576017104bcc8677a8d63322b5e1                      2.0
# fff8957ea8b240a6b5e634b6ee8eafcf                      1.0
# fffad4f4828548d1b5583907f2e9906b                      0.0
# ffff82501cea40309d5fdd7edcca4a07                      5.0
#
#                                   discount_count_viewed  discount_sum_reward  \
# person
# 0009655768c64bdeb2e877511632db8f                    1.0                  4.0
# 00116118485d4dfda04fdbaba9a87b5c                    0.0                  0.0
# 0011e0d4e6b944f998e987f904e8c1e5                    2.0                  8.0
# 0020c2b971eb4e9188eac86d93036a77                    1.0                  2.0
# 0020ccbbb6d84e358d3414a3ff76cffd                    1.0                  3.0
# ...                                                 ...                  ...
# fff3ba4757bd42088c044ca26d73817a                    1.0                  2.0
# fff7576017104bcc8677a8d63322b5e1                    2.0                  4.0
# fff8957ea8b240a6b5e634b6ee8eafcf                    1.0                  0.0
# fffad4f4828548d1b5583907f2e9906b                    0.0                  0.0
# ffff82501cea40309d5fdd7edcca4a07                    5.0                 13.0
#
#                                   informational_count_completed  \
# person
# 0009655768c64bdeb2e877511632db8f                            2.0
# 00116118485d4dfda04fdbaba9a87b5c                            0.0
# 0011e0d4e6b944f998e987f904e8c1e5                            2.0
# 0020c2b971eb4e9188eac86d93036a77                            0.0
# 0020ccbbb6d84e358d3414a3ff76cffd                            1.0
# ...                                                         ...
# fff3ba4757bd42088c044ca26d73817a                            1.0
# fff7576017104bcc8677a8d63322b5e1                            0.0
# fff8957ea8b240a6b5e634b6ee8eafcf                            0.0
# fffad4f4828548d1b5583907f2e9906b                            1.0
# ffff82501cea40309d5fdd7edcca4a07                            0.0
#
#                                   informational_count_received  \
# person
# 0009655768c64bdeb2e877511632db8f                           2.0
# 00116118485d4dfda04fdbaba9a87b5c                           0.0
# 0011e0d4e6b944f998e987f904e8c1e5                           2.0
# 0020c2b971eb4e9188eac86d93036a77                           1.0
# 0020ccbbb6d84e358d3414a3ff76cffd                           1.0
# ...                                                        ...
# fff3ba4757bd42088c044ca26d73817a                           1.0
# fff7576017104bcc8677a8d63322b5e1                           0.0
# fff8957ea8b240a6b5e634b6ee8eafcf                           1.0
# fffad4f4828548d1b5583907f2e9906b                           1.0
# ffff82501cea40309d5fdd7edcca4a07                           0.0
#
#                                   informational_count_viewed  \
# person
# 0009655768c64bdeb2e877511632db8f                         2.0
# 00116118485d4dfda04fdbaba9a87b5c                         0.0
# 0011e0d4e6b944f998e987f904e8c1e5                         2.0
# 0020c2b971eb4e9188eac86d93036a77                         1.0
# 0020ccbbb6d84e358d3414a3ff76cffd                         1.0
# ...                                                      ...
# fff3ba4757bd42088c044ca26d73817a                         1.0
# fff7576017104bcc8677a8d63322b5e1                         0.0
# fff8957ea8b240a6b5e634b6ee8eafcf                         0.0
# fffad4f4828548d1b5583907f2e9906b                         1.0
# ffff82501cea40309d5fdd7edcca4a07                         0.0
#
#                                   informational_sum_reward
# person
# 0009655768c64bdeb2e877511632db8f                       0.0
# 00116118485d4dfda04fdbaba9a87b5c                       0.0
# 0011e0d4e6b944f998e987f904e8c1e5                       0.0
# 0020c2b971eb4e9188eac86d93036a77                       0.0
# 0020ccbbb6d84e358d3414a3ff76cffd                       0.0
# ...                                                    ...
# fff3ba4757bd42088c044ca26d73817a                       0.0
# fff7576017104bcc8677a8d63322b5e1                       0.0
# fff8957ea8b240a6b5e634b6ee8eafcf                       0.0
# fffad4f4828548d1b5583907f2e9906b                       0.0
# ffff82501cea40309d5fdd7edcca4a07                       0.0
#
# [16994 rows x 12 columns]

# %%
def filter_time_range(df_ele,trange):
    if (df_ele['time']>=trange[0]) and (df_ele['time']<=trange[1]):
        return df_ele['amount']
    else:
        return np.nan

# %%
# sample_trans = transcript[transcript['person']=='0cc6e8553c844c02ab525bc466aa569b']
# sample =customer_offers[customer_offers['person']=='0cc6e8553c844c02ab525bc466aa569b']
# sub_group_ranges = list(zip(sample['time viewed'], sample['time completed']))

# %%
# find_min_max = [min(x) for x in sub_group_ranges]+[max(x) for x in sub_group_ranges]
# min_ = min(find_min_max)
# max_ = max(find_min_max)
# temp_ary = np.arange(min_,max_+1)
# temp_dic = dict((el,0) for el in temp_ary)
# print(min_,max_)

# for tup in sub_group_ranges:
#     print(tup)
    
#     if not(np.isnan(np.sum(tup))):
#         run_ary = (np.arange(tup[0],tup[1]+1))
#         print(run_ary)
#         for j in run_ary:
#             temp_dic[j]=temp_dic[j]+1
            
# temp_dic

# %%
# for trange in sub_group_ranges:
#     print(trange)
#     sample_trans[str(trange)] = sample_trans.apply(lambda x: filter_time_range(x,trange),axis=1)
# dfg_per_offer=sample_trans.groupby(['person']).sum()

# %%
# people = list(transcript['person'])[:100]
# for person in people:
#     if (transcript[transcript['person']==person]['amount'].value_counts().max()) > 1:
#         print(person)

# %%
# transcript[transcript['person']==person]['amount'].value_counts().max()

# %%
# sample_trans = transcript[transcript['person']=='0cc6e8553c844c02ab525bc466aa569b']
# sample =customer_offers[customer_offers['person']=='0cc6e8553c844c02ab525bc466aa569b']
# sub_group_ranges = list(zip(sample['time viewed'], sample['time completed']))

def overlap(sub_group_ranges):
    valid_ranges = []
    #print(sub_group_ranges)
    for tup in sub_group_ranges:
        if not (np.isnan(np.sum(tup))):
           # print(np.sum(tup))
            valid_ranges.append(tup)
        #    sub_group_ranges.remove(tup)
   # print(valid_ranges)        
    tuple_list =[] 
    if len(valid_ranges)>0:
        for tup in valid_ranges:
            tuple_list.append(np.arange(tup[0],tup[1]))
    
    if len(tuple_list)>0:
        xs = set(tuple_list[0])
        count = len(tuple_list[0])
        for item in tuple_list[1:]:
            xs = xs.union(item)
            count = count + len(item)
    else:
        count = 0
        xs = set()
    if len(xs) < count:
        return 1
    else:
        return 0

# %%
# np.sum((np.nan, 594.0))
# overlap([(60.0, 186.0), (336.0, 342.0), (168.0, np.nan), (np.nan, 594.0), (510.0, 594.0), (576.0, 594.0)])
# overlap([(108.0, np.nan), (504.0, 522.0), (174.0, 252.0), (336.0, 342.0), (594.0, 630.0), (np.nan, np.nan)])
# p = list(transcript.groupby('person').count().sort_values('event', ascending=False).index)
# p.index('0cc6e8553c844c02ab525bc466aa569b')

# %%
# %%time
file_name = 'df_person_money_spent_inc_overlap.pkl'
sub_group_ranges=None
collected_sub_group_ranges = None
#df_person_money_spent=None
if os.path.isfile(file_name):
    df_person_money_spent = pd.read_pickle(file_name)
    print('read file {}'.format(file_name))
else:
    person_list =list(transcript.groupby('person').count().sort_values('event', ascending=False).index)[:80]
    person_money_spent = []
    person_money_spent_per_offer=[]
    overlap_list=[]
    for i, person in enumerate(person_list):
        df_offer = pd.DataFrame()
        if i%100==0:
            print(i,' person evaluated')
        offer_list = [str(x) for x in list(transcript[transcript['person']==person]['offer_id'].unique())]
        if 'None' in offer_list : offer_list.remove('None')
        person_money_spent_per_offer=[]
        collected_sub_group_ranges=[]
        for offer_id in offer_list:
           # print(offer_id)
            df = transcript.loc[transcript['person']==person].copy()
            sample = customer_offers.loc[(customer_offers['person']==person) & (customer_offers['offer_id']==offer_id)]
            sub_group_ranges = list(zip(sample['time_viewed'], sample['time_completed']))
            collected_sub_group_ranges = collected_sub_group_ranges+sub_group_ranges
            for trange in sub_group_ranges:
                df[str(trange)] = df.apply(lambda x: filter_time_range(x,trange),axis=1)
            dfg_per_offer=df.groupby(['person']).sum()
            sub_result = pd.concat([dfg_per_offer.iloc[:,:3],dfg_per_offer.iloc[:,3:].sum(axis=1)],axis=1)
            sub_result['offer_id'] = offer_id
            
            person_money_spent_per_offer.append(sub_result)
           # print(len(person_money_spent_per_offer))
        if len(offer_list) >0:
            df_person_money_spent_per_offer = pd.concat(person_money_spent_per_offer,axis=0)
            #print(collected_sub_group_ranges)
            overlap_status = overlap(collected_sub_group_ranges)
           # print('overlap: ',overlap_status)
            df_person_money_spent_per_offer['overlap'] = overlap_status
            person_money_spent.append(df_person_money_spent_per_offer)
        
    df_person_money_spent = pd.concat(person_money_spent,axis=0)
    df_person_money_spent.rename(columns={0:'spent_in_offer'},inplace=True)
    df_person_money_spent.to_pickle(file_name)
    print('wrote file {}'.format(file_name))
# Out:
# read file df_person_money_spent_inc_overlap.pkl
# CPU times: user 9.62 ms, sys: 8.08 ms, total: 17.7 ms
# Wall time: 16.8 ms

# %% [markdown]
# some of the results overlap. this means that more than one offer is active per customer at the same time(viewed and not yet completed). since they are only less than 9 % of the data they will be excluded. otherwise the amount spent during an offer would be counted multiple times.

# %%
df_person_money_spent
# Out:
#                                    time  amount  reward  spent_in_offer  \
# person
# 94de646f7b6041228ca7dec82adb97d2  20586   90.23    22.0            7.41
# 94de646f7b6041228ca7dec82adb97d2  20586   90.23    22.0           30.84
# 94de646f7b6041228ca7dec82adb97d2  20586   90.23    22.0            0.00
# 94de646f7b6041228ca7dec82adb97d2  20586   90.23    22.0           11.01
# 94de646f7b6041228ca7dec82adb97d2  20586   90.23    22.0            0.00
# ...                                 ...     ...     ...             ...
# 22617705eec442e0b7b43e5c5f56fb17   1008    0.00     0.0            0.00
# 3045af4e98794a04a5542d3eac939b1f   1152    0.00     0.0            0.00
# 1bfe13d2453c4185a6486c6817e0d568    720    0.00     0.0            0.00
# 3a4e53046c544134bb1e7782248631d1    840    0.00     0.0            0.00
# cae5e211053f4121a389a7da4d631f7f    828    0.00     0.0            0.00
#
#                                                           offer_id  overlap  \
# person
# 94de646f7b6041228ca7dec82adb97d2  f19421c1d4aa40978ebb69ca19b0e20d        0
# 94de646f7b6041228ca7dec82adb97d2  9b98b8c7a33c4b65b9aebfe6a799e6d9        0
# 94de646f7b6041228ca7dec82adb97d2  0b1e1539f2cc45b7b9fa7c272da2e1d7        0
# 94de646f7b6041228ca7dec82adb97d2  fafdcd668e3743c1bb461111dcafc2a4        0
# 94de646f7b6041228ca7dec82adb97d2  4d5c57ea9a6940dd891ad53e9dbe8da0        0
# ...                                                            ...      ...
# 22617705eec442e0b7b43e5c5f56fb17  f19421c1d4aa40978ebb69ca19b0e20d        0
# 3045af4e98794a04a5542d3eac939b1f  4d5c57ea9a6940dd891ad53e9dbe8da0        0
# 1bfe13d2453c4185a6486c6817e0d568  ae264e3637204a6fb9bb56bc8210ddfd        0
# 3a4e53046c544134bb1e7782248631d1  9b98b8c7a33c4b65b9aebfe6a799e6d9        0
# cae5e211053f4121a389a7da4d631f7f  fafdcd668e3743c1bb461111dcafc2a4        0
#
#                                  offer_type
# person
# 94de646f7b6041228ca7dec82adb97d2       bogo
# 94de646f7b6041228ca7dec82adb97d2       bogo
# 94de646f7b6041228ca7dec82adb97d2   discount
# 94de646f7b6041228ca7dec82adb97d2   discount
# 94de646f7b6041228ca7dec82adb97d2       bogo
# ...                                     ...
# 22617705eec442e0b7b43e5c5f56fb17       bogo
# 3045af4e98794a04a5542d3eac939b1f       bogo
# 1bfe13d2453c4185a6486c6817e0d568       bogo
# 3a4e53046c544134bb1e7782248631d1       bogo
# cae5e211053f4121a389a7da4d631f7f   discount
#
# [57722 rows x 7 columns]

# %%
len(df_person_money_spent[df_person_money_spent['overlap']==1])/len(df_person_money_spent)
# Out:
# 0.08794716217924409

# %% [markdown]
# following data frame ```df_person_money_spent``` represents how much a single person spent while an offer was active. if similar offers were sent to the same person it is the sum of spendings. to group further we can pivot the table for person in rows and offers in columns or for a less deep analysis by only reward-type in columns

# %%
group_spending = ['offer_id']
group_spending = ['offer_type']
df_person_money_spent=df_person_money_spent[df_person_money_spent['overlap']==0].copy()
df_person_money_spent['offer_type'] = df_person_money_spent['offer_id'].apply(lambda x: look_up_offer_type[x])

df_person_money_spent_pivot = pd.pivot_table(df_person_money_spent, index=['person'], columns=group_spending, aggfunc={'spent_in_offer':'sum'})
df_person_money_spent_pivot.columns = df_person_money_spent_pivot.columns.swaplevel(0,1)
df_person_money_spent_pivot.sort_index(axis=1,  inplace=True)
df_person_money_spent_pivot.fillna(value=0,inplace=True)
# df_person_money_spent_pivot.columns.set_levels(['non rewarded','rewarded'],level=0,inplace=True)
df_person_money_spent_pivot.columns = ['%s%s' % (a, '_%s' % b if b else '') for a, b in df_person_money_spent_pivot.columns]
#person_spendings_by_offer=df_person_money_spent_pivot.droplevel(0,axis=1)
df_person_money_spent_pivot
# Out:
#                                   bogo_spent_in_offer  \
# person
# 0009655768c64bdeb2e877511632db8f                 0.00
# 00116118485d4dfda04fdbaba9a87b5c                 0.00
# 0020c2b971eb4e9188eac86d93036a77                17.24
# 0020ccbbb6d84e358d3414a3ff76cffd                24.85
# 00426fe3ffde4c6b9cb9ad6d077a13ea                 0.00
# ...                                               ...
# fff3ba4757bd42088c044ca26d73817a                 0.00
# fff7576017104bcc8677a8d63322b5e1                 0.00
# fff8957ea8b240a6b5e634b6ee8eafcf                 0.00
# fffad4f4828548d1b5583907f2e9906b                19.15
# ffff82501cea40309d5fdd7edcca4a07                 0.00
#
#                                   discount_spent_in_offer  \
# person
# 0009655768c64bdeb2e877511632db8f                     0.00
# 00116118485d4dfda04fdbaba9a87b5c                     0.00
# 0020c2b971eb4e9188eac86d93036a77                    17.63
# 0020ccbbb6d84e358d3414a3ff76cffd                    11.65
# 00426fe3ffde4c6b9cb9ad6d077a13ea                    23.34
# ...                                                   ...
# fff3ba4757bd42088c044ca26d73817a                    20.98
# fff7576017104bcc8677a8d63322b5e1                    21.63
# fff8957ea8b240a6b5e634b6ee8eafcf                     0.00
# fffad4f4828548d1b5583907f2e9906b                     0.00
# ffff82501cea40309d5fdd7edcca4a07                    72.06
#
#                                   informational_spent_in_offer
# person
# 0009655768c64bdeb2e877511632db8f                         30.73
# 00116118485d4dfda04fdbaba9a87b5c                          0.00
# 0020c2b971eb4e9188eac86d93036a77                          0.00
# 0020ccbbb6d84e358d3414a3ff76cffd                         58.87
# 00426fe3ffde4c6b9cb9ad6d077a13ea                         25.92
# ...                                                        ...
# fff3ba4757bd42088c044ca26d73817a                        414.31
# fff7576017104bcc8677a8d63322b5e1                          0.00
# fff8957ea8b240a6b5e634b6ee8eafcf                          0.00
# fffad4f4828548d1b5583907f2e9906b                          5.63
# ffff82501cea40309d5fdd7edcca4a07                          0.00
#
# [15646 rows x 3 columns]

# %% [markdown]
# now we can start to build a data frame holding demographic data and data derrived from calculations on how much a customer spends regarding a certain offer
# - taking the base profile dataset containing demographic information
# - concatenating with information about spendings and rewards per offer
# - concatenating with spendings and rewards in general

# %%
profile_for_merge = profile.copy()
profile_for_merge.index = profile_for_merge.id
profile_for_merge.drop('id',axis=1,inplace=True)
profile_for_merge
# Out:
#                                  gender  age  became_member_on    income
# id
# 0610b486422d4921ae7d2bf64640c50b      F   55          20170715  112000.0
# 78afa995795e4d85b5d9ceeca43f5fef      F   75          20170509  100000.0
# e2127556f4f64592b11af22de27a7932      M   68          20180426   70000.0
# 389bc3fa690240e798340f5a15918d5c      M   65          20180209   53000.0
# 2eeac8d8feae4a8cad5a6af0499a211d      M   58          20171111   51000.0
# ...                                 ...  ...               ...       ...
# 6d5f3a774f3d4714ab0c092238f3a1d7      F   45          20180604   54000.0
# 2cb4f97358b841b9a9773a7aa05a9d77      M   61          20180713   72000.0
# 01d26f638c274aa0b965d24cefe3183f      M   49          20170126   73000.0
# 9dc1421481194dcd9400aec7c9ae6366      F   83          20160307   50000.0
# e4052622e5ba45a8b96b59aba68cf068      F   62          20170722   82000.0
#
# [14825 rows x 4 columns]

# %%
amount_spent = transcript.groupby('person').agg({'amount':'sum'})
amount_spent.columns = ['amount_spent_total']

# %%
df_to_combine=[offer_counts_pivot,df_person_money_spent_pivot,amount_spent,profile_for_merge]
                   

joined_part1 = pd.merge(profile_for_merge, offer_counts_pivot, how='inner', left_index=True, right_index=True)
joined_part2 = pd.merge(joined_part1, df_person_money_spent_pivot, how='inner', left_index=True, right_index=True)
customers = pd.merge(joined_part2, amount_spent, how='inner', left_index=True, right_index=True)
customers.sort_index(axis=1,  inplace=True)

#joined = pd.concat(df_to_combine,axis=1, sort=False)
print([len(x) for x in df_to_combine]+[len(customers)])
# Out:
# [16994, 15646, 17000, 14825, 13573]

# %%
customers[customers.index.str.startswith('0cc6e8553c844c02ab525bc466aa569b')]
# Out:
# Empty DataFrame
# Columns: [age, amount_spent_total, became_member_on, bogo_count_completed, bogo_count_received, bogo_count_viewed, bogo_spent_in_offer, bogo_sum_reward, discount_count_completed, discount_count_received, discount_count_viewed, discount_spent_in_offer, discount_sum_reward, gender, income, informational_count_completed, informational_count_received, informational_count_viewed, informational_spent_in_offer, informational_sum_reward]
# Index: []

# %%
customers.sort_values('bogo_spent_in_offer')
# Out:
#                                   age  amount_spent_total  became_member_on  \
# 0610b486422d4921ae7d2bf64640c50b   55               77.01          20170715
# 346ca0b690b44443a4fc2bd747964066   52              139.92          20160408
# e648d51c487040748182aad1201ce7a3   55               70.48          20180419
# 2eede32dd09743bdb5e6143dd8db7b10   50              149.92          20170328
# a67060333adb4e4aa700c015850e2002   62               57.35          20160802
# ...                               ...                 ...               ...
# ff2113310abe4c6687569bdd8f028fe3   55              973.74          20170508
# 3c7108e2cf594134ac0bb027e040afb5   60             1039.27          20180116
# a12fba072dae4e3aae2e1b4b92b92aa1   55             1011.82          20160420
# 05bedc6bbcc64a41b1745f6efe00776d   70             1148.92          20150729
# 454b00bdd77c4f588eb9f6cafd81dc5d   53             1087.98          20180329
#
#                                   bogo_count_completed  bogo_count_received  \
# 0610b486422d4921ae7d2bf64640c50b                   1.0                  1.0
# 346ca0b690b44443a4fc2bd747964066                   1.0                  1.0
# e648d51c487040748182aad1201ce7a3                   0.0                  1.0
# 2eede32dd09743bdb5e6143dd8db7b10                   0.0                  0.0
# a67060333adb4e4aa700c015850e2002                   0.0                  0.0
# ...                                                ...                  ...
# ff2113310abe4c6687569bdd8f028fe3                   1.0                  1.0
# 3c7108e2cf594134ac0bb027e040afb5                   3.0                  3.0
# a12fba072dae4e3aae2e1b4b92b92aa1                   1.0                  1.0
# 05bedc6bbcc64a41b1745f6efe00776d                   3.0                  3.0
# 454b00bdd77c4f588eb9f6cafd81dc5d                   1.0                  1.0
#
#                                   bogo_count_viewed  bogo_spent_in_offer  \
# 0610b486422d4921ae7d2bf64640c50b                0.0                 0.00
# 346ca0b690b44443a4fc2bd747964066                0.0                 0.00
# e648d51c487040748182aad1201ce7a3                1.0                 0.00
# 2eede32dd09743bdb5e6143dd8db7b10                0.0                 0.00
# a67060333adb4e4aa700c015850e2002                0.0                 0.00
# ...                                             ...                  ...
# ff2113310abe4c6687569bdd8f028fe3                1.0               841.45
# 3c7108e2cf594134ac0bb027e040afb5                2.0               864.57
# a12fba072dae4e3aae2e1b4b92b92aa1                1.0               871.51
# 05bedc6bbcc64a41b1745f6efe00776d                3.0               979.41
# 454b00bdd77c4f588eb9f6cafd81dc5d                1.0              1015.73
#
#                                   bogo_sum_reward  discount_count_completed  \
# 0610b486422d4921ae7d2bf64640c50b              5.0                       0.0
# 346ca0b690b44443a4fc2bd747964066              5.0                       2.0
# e648d51c487040748182aad1201ce7a3              0.0                       1.0
# 2eede32dd09743bdb5e6143dd8db7b10              0.0                       1.0
# a67060333adb4e4aa700c015850e2002              0.0                       2.0
# ...                                           ...                       ...
# ff2113310abe4c6687569bdd8f028fe3             10.0                       3.0
# 3c7108e2cf594134ac0bb027e040afb5             20.0                       1.0
# a12fba072dae4e3aae2e1b4b92b92aa1             10.0                       2.0
# 05bedc6bbcc64a41b1745f6efe00776d             20.0                       0.0
# 454b00bdd77c4f588eb9f6cafd81dc5d             10.0                       0.0
#
#                                   discount_count_received  \
# 0610b486422d4921ae7d2bf64640c50b                      0.0
# 346ca0b690b44443a4fc2bd747964066                      2.0
# e648d51c487040748182aad1201ce7a3                      1.0
# 2eede32dd09743bdb5e6143dd8db7b10                      1.0
# a67060333adb4e4aa700c015850e2002                      3.0
# ...                                                   ...
# ff2113310abe4c6687569bdd8f028fe3                      3.0
# 3c7108e2cf594134ac0bb027e040afb5                      1.0
# a12fba072dae4e3aae2e1b4b92b92aa1                      3.0
# 05bedc6bbcc64a41b1745f6efe00776d                      0.0
# 454b00bdd77c4f588eb9f6cafd81dc5d                      0.0
#
#                                   discount_count_viewed  \
# 0610b486422d4921ae7d2bf64640c50b                    0.0
# 346ca0b690b44443a4fc2bd747964066                    2.0
# e648d51c487040748182aad1201ce7a3                    1.0
# 2eede32dd09743bdb5e6143dd8db7b10                    1.0
# a67060333adb4e4aa700c015850e2002                    3.0
# ...                                                 ...
# ff2113310abe4c6687569bdd8f028fe3                    1.0
# 3c7108e2cf594134ac0bb027e040afb5                    1.0
# a12fba072dae4e3aae2e1b4b92b92aa1                    1.0
# 05bedc6bbcc64a41b1745f6efe00776d                    0.0
# 454b00bdd77c4f588eb9f6cafd81dc5d                    0.0
#
#                                   discount_spent_in_offer  \
# 0610b486422d4921ae7d2bf64640c50b                     0.00
# 346ca0b690b44443a4fc2bd747964066                    36.04
# e648d51c487040748182aad1201ce7a3                    27.66
# 2eede32dd09743bdb5e6143dd8db7b10                    12.18
# a67060333adb4e4aa700c015850e2002                    23.97
# ...                                                   ...
# ff2113310abe4c6687569bdd8f028fe3                     0.00
# 3c7108e2cf594134ac0bb027e040afb5                    33.22
# a12fba072dae4e3aae2e1b4b92b92aa1                     0.00
# 05bedc6bbcc64a41b1745f6efe00776d                     0.00
# 454b00bdd77c4f588eb9f6cafd81dc5d                     0.00
#
#                                   discount_sum_reward gender    income  \
# 0610b486422d4921ae7d2bf64640c50b                  0.0      F  112000.0
# 346ca0b690b44443a4fc2bd747964066                  5.0      F   85000.0
# e648d51c487040748182aad1201ce7a3                  2.0      F   82000.0
# 2eede32dd09743bdb5e6143dd8db7b10                  2.0      F   62000.0
# a67060333adb4e4aa700c015850e2002                  7.0      M   94000.0
# ...                                               ...    ...       ...
# ff2113310abe4c6687569bdd8f028fe3                  9.0      M  100000.0
# 3c7108e2cf594134ac0bb027e040afb5                  3.0      F   99000.0
# a12fba072dae4e3aae2e1b4b92b92aa1                  4.0      F   97000.0
# 05bedc6bbcc64a41b1745f6efe00776d                  0.0      F  105000.0
# 454b00bdd77c4f588eb9f6cafd81dc5d                  0.0      F   89000.0
#
#                                   informational_count_completed  \
# 0610b486422d4921ae7d2bf64640c50b                            0.0
# 346ca0b690b44443a4fc2bd747964066                            0.0
# e648d51c487040748182aad1201ce7a3                            1.0
# 2eede32dd09743bdb5e6143dd8db7b10                            2.0
# a67060333adb4e4aa700c015850e2002                            1.0
# ...                                                         ...
# ff2113310abe4c6687569bdd8f028fe3                            0.0
# 3c7108e2cf594134ac0bb027e040afb5                            1.0
# a12fba072dae4e3aae2e1b4b92b92aa1                            0.0
# 05bedc6bbcc64a41b1745f6efe00776d                            2.0
# 454b00bdd77c4f588eb9f6cafd81dc5d                            0.0
#
#                                   informational_count_received  \
# 0610b486422d4921ae7d2bf64640c50b                           1.0
# 346ca0b690b44443a4fc2bd747964066                           1.0
# e648d51c487040748182aad1201ce7a3                           2.0
# 2eede32dd09743bdb5e6143dd8db7b10                           2.0
# a67060333adb4e4aa700c015850e2002                           1.0
# ...                                                        ...
# ff2113310abe4c6687569bdd8f028fe3                           0.0
# 3c7108e2cf594134ac0bb027e040afb5                           1.0
# a12fba072dae4e3aae2e1b4b92b92aa1                           1.0
# 05bedc6bbcc64a41b1745f6efe00776d                           2.0
# 454b00bdd77c4f588eb9f6cafd81dc5d                           1.0
#
#                                   informational_count_viewed  \
# 0610b486422d4921ae7d2bf64640c50b                         0.0
# 346ca0b690b44443a4fc2bd747964066                         0.0
# e648d51c487040748182aad1201ce7a3                         2.0
# 2eede32dd09743bdb5e6143dd8db7b10                         2.0
# a67060333adb4e4aa700c015850e2002                         1.0
# ...                                                      ...
# ff2113310abe4c6687569bdd8f028fe3                         0.0
# 3c7108e2cf594134ac0bb027e040afb5                         1.0
# a12fba072dae4e3aae2e1b4b92b92aa1                         0.0
# 05bedc6bbcc64a41b1745f6efe00776d                         2.0
# 454b00bdd77c4f588eb9f6cafd81dc5d                         0.0
#
#                                   informational_spent_in_offer  \
# 0610b486422d4921ae7d2bf64640c50b                          0.00
# 346ca0b690b44443a4fc2bd747964066                          0.00
# e648d51c487040748182aad1201ce7a3                          0.00
# 2eede32dd09743bdb5e6143dd8db7b10                         14.98
# a67060333adb4e4aa700c015850e2002                          0.00
# ...                                                        ...
# ff2113310abe4c6687569bdd8f028fe3                          0.00
# 3c7108e2cf594134ac0bb027e040afb5                          0.00
# a12fba072dae4e3aae2e1b4b92b92aa1                          0.00
# 05bedc6bbcc64a41b1745f6efe00776d                         50.04
# 454b00bdd77c4f588eb9f6cafd81dc5d                          0.00
#
#                                   informational_sum_reward
# 0610b486422d4921ae7d2bf64640c50b                       0.0
# 346ca0b690b44443a4fc2bd747964066                       0.0
# e648d51c487040748182aad1201ce7a3                       0.0
# 2eede32dd09743bdb5e6143dd8db7b10                       0.0
# a67060333adb4e4aa700c015850e2002                       0.0
# ...                                                    ...
# ff2113310abe4c6687569bdd8f028fe3                       0.0
# 3c7108e2cf594134ac0bb027e040afb5                       0.0
# a12fba072dae4e3aae2e1b4b92b92aa1                       0.0
# 05bedc6bbcc64a41b1745f6efe00776d                       0.0
# 454b00bdd77c4f588eb9f6cafd81dc5d                       0.0
#
# [13573 rows x 20 columns]

# %%
customers.describe()
# Out:
#                 age  amount_spent_total  became_member_on  \
# count  13573.000000        13573.000000      1.357300e+04
# mean      54.225890          115.293461      2.016693e+07
# std       17.471355          129.878095      1.185279e+04
# min       18.000000            0.000000      2.013073e+07
# 25%       42.000000           28.850000      2.016052e+07
# 50%       55.000000           83.980000      2.017080e+07
# 75%       66.000000          160.350000      2.017123e+07
# max      101.000000         1608.690000      2.018073e+07
#
#        bogo_count_completed  bogo_count_received  bogo_count_viewed  \
# count          13573.000000         13573.000000       13573.000000
# mean               0.939218             1.701171           1.461283
# std                1.011606             1.053951           1.042881
# min                0.000000             0.000000           0.000000
# 25%                0.000000             1.000000           1.000000
# 50%                1.000000             2.000000           1.000000
# 75%                2.000000             2.000000           2.000000
# max                5.000000             6.000000           6.000000
#
#        bogo_spent_in_offer  bogo_sum_reward  discount_count_completed  \
# count         13573.000000     13573.000000              13573.000000
# mean             14.642602         6.864363                  1.033817
# std              37.476393         7.941019                  1.019753
# min               0.000000         0.000000                  0.000000
# 25%               0.000000         0.000000                  0.000000
# 50%               0.000000         5.000000                  1.000000
# 75%              21.750000        10.000000                  2.000000
# max            1015.730000        50.000000                  5.000000
#
#        discount_count_received  discount_count_viewed  \
# count             13573.000000           13573.000000
# mean                  1.639726               1.186105
# std                   1.022812               0.992527
# min                   0.000000               0.000000
# 25%                   1.000000               0.000000
# 50%                   2.000000               1.000000
# 75%                   2.000000               2.000000
# max                   6.000000               6.000000
#
#        discount_spent_in_offer  discount_sum_reward         income  \
# count             13573.000000         13573.000000   13573.000000
# mean                 14.967064             2.932513   65162.086495
# std                  35.058615             3.077568   21814.826036
# min                   0.000000             0.000000   30000.000000
# 25%                   0.000000             0.000000   48000.000000
# 50%                   6.130000             2.000000   63000.000000
# 75%                  22.280000             5.000000   79000.000000
# max                1033.780000            18.000000  120000.000000
#
#        informational_count_completed  informational_count_received  \
# count                   13573.000000                  13573.000000
# mean                        0.553157                      0.822736
# std                         0.717497                      0.785286
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      1.000000
# 75%                         1.000000                      1.000000
# max                         4.000000                      5.000000
#
#        informational_count_viewed  informational_spent_in_offer  \
# count                13573.000000                  13573.000000
# mean                     0.608193                      8.098500
# std                      0.744583                     27.317558
# min                      0.000000                      0.000000
# 25%                      0.000000                      0.000000
# 50%                      0.000000                      0.000000
# 75%                      1.000000                      3.360000
# max                      5.000000                    777.470000
#
#        informational_sum_reward
# count                   13573.0
# mean                        0.0
# std                         0.0
# min                         0.0
# 25%                         0.0
# 50%                         0.0
# 75%                         0.0
# max                         0.0

# %%
customers.to_excel('customers.xlsx')
customers.to_csv('customers.csv')

# %% [markdown]
# ## KPI s for person
# Lets first grab a list of features that come to mind when wanting to analyze the customers behvaiour.
#
# - count offers received
# - count offers viewed
# - count transactions
# - count offers completed
# - total ammount spent
# - view_ratio
# - transaction_ratio
# - completeness_ratio
# - ammount spent during offer A
# - ammount spent outside offer
# - time being customer

# %% [markdown]
# checking conversion rate of each offer type

# %%
customers.columns
# Out:
# Index(['age', 'amount spent total', 'became_member_on', 'bogo count completed',
#        'bogo count received', 'bogo count viewed', 'bogo spent in offer',
#        'bogo sum reward', 'discount count completed',
#        'discount count received', 'discount count viewed',
#        'discount spent in offer', 'discount sum reward', 'gender', 'income',
#        'informational count completed', 'informational count received',
#        'informational count viewed', 'informational spent in offer',
#        'informational sum reward'],
#       dtype='object')

# %%
cr_bogo = customers['bogo_count_completed'].sum()/customers['bogo_count_received'].sum()
cr_discount = customers['discount_count_completed'].sum()/customers['discount_count_received'].sum()
cr_information = customers['informational_count_completed'].sum()/customers['informational_count_received'].sum()
print(cr_bogo,cr_discount,cr_information)
# Out:
# 0.5521004763967086 0.6304816678648454 0.672338139160025

# %% [markdown]
# the high conversion rate of informational offers might be due to the fact that the initial description of the dataset suggests that an informational offer influences the customer for its given duration. this might be too long and can be used as a parameter to tweak later. however the amount spent on informational offers is less then in rewarded offers - roughly half regarding the other offers individually

# %%
sum_bogo = customers['bogo_spent_in_offer'].sum()
sum_discount = customers['discount_spent_in_offer'].sum()
sum_information = customers['informational_spent_in_offer'].sum()
print(sum_bogo,sum_discount,sum_information)
# Out:
# 198744.04 203147.96000000002 109920.94

# %%
customers
# Out:
#                                   age  amount_spent_total  became_member_on  \
# 0610b486422d4921ae7d2bf64640c50b   55               77.01          20170715
# 78afa995795e4d85b5d9ceeca43f5fef   75              159.27          20170509
# e2127556f4f64592b11af22de27a7932   68               57.73          20180426
# 2eeac8d8feae4a8cad5a6af0499a211d   58               15.62          20171111
# aa4862eba776480b8bb9c68455b8c2e1   61               85.55          20170911
# ...                               ...                 ...               ...
# 6d5f3a774f3d4714ab0c092238f3a1d7   45               20.03          20180604
# 2cb4f97358b841b9a9773a7aa05a9d77   61               25.97          20180713
# 01d26f638c274aa0b965d24cefe3183f   49               39.74          20170126
# 9dc1421481194dcd9400aec7c9ae6366   83              189.67          20160307
# e4052622e5ba45a8b96b59aba68cf068   62              143.02          20170722
#
#                                   bogo_count_completed  bogo_count_received  \
# 0610b486422d4921ae7d2bf64640c50b                   1.0                  1.0
# 78afa995795e4d85b5d9ceeca43f5fef                   3.0                  3.0
# e2127556f4f64592b11af22de27a7932                   1.0                  1.0
# 2eeac8d8feae4a8cad5a6af0499a211d                   0.0                  0.0
# aa4862eba776480b8bb9c68455b8c2e1                   3.0                  3.0
# ...                                                ...                  ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                   0.0                  1.0
# 2cb4f97358b841b9a9773a7aa05a9d77                   1.0                  1.0
# 01d26f638c274aa0b965d24cefe3183f                   0.0                  0.0
# 9dc1421481194dcd9400aec7c9ae6366                   3.0                  3.0
# e4052622e5ba45a8b96b59aba68cf068                   1.0                  1.0
#
#                                   bogo_count_viewed  bogo_spent_in_offer  \
# 0610b486422d4921ae7d2bf64640c50b                0.0                 0.00
# 78afa995795e4d85b5d9ceeca43f5fef                3.0                41.61
# e2127556f4f64592b11af22de27a7932                1.0                18.42
# 2eeac8d8feae4a8cad5a6af0499a211d                0.0                 0.00
# aa4862eba776480b8bb9c68455b8c2e1                3.0                24.89
# ...                                             ...                  ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                1.0                 0.00
# 2cb4f97358b841b9a9773a7aa05a9d77                0.0                 0.00
# 01d26f638c274aa0b965d24cefe3183f                0.0                 0.00
# 9dc1421481194dcd9400aec7c9ae6366                3.0                20.24
# e4052622e5ba45a8b96b59aba68cf068                1.0                 0.00
#
#                                   bogo_sum_reward  discount_count_completed  \
# 0610b486422d4921ae7d2bf64640c50b              5.0                       0.0
# 78afa995795e4d85b5d9ceeca43f5fef             20.0                       0.0
# e2127556f4f64592b11af22de27a7932              5.0                       1.0
# 2eeac8d8feae4a8cad5a6af0499a211d              0.0                       1.0
# aa4862eba776480b8bb9c68455b8c2e1             25.0                       0.0
# ...                                           ...                       ...
# 6d5f3a774f3d4714ab0c092238f3a1d7              0.0                       0.0
# 2cb4f97358b841b9a9773a7aa05a9d77              5.0                       0.0
# 01d26f638c274aa0b965d24cefe3183f              0.0                       0.0
# 9dc1421481194dcd9400aec7c9ae6366             25.0                       0.0
# e4052622e5ba45a8b96b59aba68cf068              5.0                       1.0
#
#                                   discount_count_received  \
# 0610b486422d4921ae7d2bf64640c50b                      0.0
# 78afa995795e4d85b5d9ceeca43f5fef                      0.0
# e2127556f4f64592b11af22de27a7932                      2.0
# 2eeac8d8feae4a8cad5a6af0499a211d                      2.0
# aa4862eba776480b8bb9c68455b8c2e1                      1.0
# ...                                                   ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                      1.0
# 2cb4f97358b841b9a9773a7aa05a9d77                      0.0
# 01d26f638c274aa0b965d24cefe3183f                      1.0
# 9dc1421481194dcd9400aec7c9ae6366                      0.0
# e4052622e5ba45a8b96b59aba68cf068                      1.0
#
#                                   discount_count_viewed  \
# 0610b486422d4921ae7d2bf64640c50b                    0.0
# 78afa995795e4d85b5d9ceeca43f5fef                    0.0
# e2127556f4f64592b11af22de27a7932                    2.0
# 2eeac8d8feae4a8cad5a6af0499a211d                    2.0
# aa4862eba776480b8bb9c68455b8c2e1                    1.0
# ...                                                 ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                    1.0
# 2cb4f97358b841b9a9773a7aa05a9d77                    0.0
# 01d26f638c274aa0b965d24cefe3183f                    0.0
# 9dc1421481194dcd9400aec7c9ae6366                    0.0
# e4052622e5ba45a8b96b59aba68cf068                    1.0
#
#                                   discount_spent_in_offer  \
# 0610b486422d4921ae7d2bf64640c50b                     0.00
# 78afa995795e4d85b5d9ceeca43f5fef                     0.00
# e2127556f4f64592b11af22de27a7932                    18.42
# 2eeac8d8feae4a8cad5a6af0499a211d                    12.43
# aa4862eba776480b8bb9c68455b8c2e1                     0.00
# ...                                                   ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                     0.00
# 2cb4f97358b841b9a9773a7aa05a9d77                     0.00
# 01d26f638c274aa0b965d24cefe3183f                     0.00
# 9dc1421481194dcd9400aec7c9ae6366                     0.00
# e4052622e5ba45a8b96b59aba68cf068                    21.55
#
#                                   discount_sum_reward gender    income  \
# 0610b486422d4921ae7d2bf64640c50b                  0.0      F  112000.0
# 78afa995795e4d85b5d9ceeca43f5fef                  0.0      F  100000.0
# e2127556f4f64592b11af22de27a7932                  2.0      M   70000.0
# 2eeac8d8feae4a8cad5a6af0499a211d                  2.0      M   51000.0
# aa4862eba776480b8bb9c68455b8c2e1                  0.0      F   57000.0
# ...                                               ...    ...       ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                  0.0      F   54000.0
# 2cb4f97358b841b9a9773a7aa05a9d77                  0.0      M   72000.0
# 01d26f638c274aa0b965d24cefe3183f                  0.0      M   73000.0
# 9dc1421481194dcd9400aec7c9ae6366                  0.0      F   50000.0
# e4052622e5ba45a8b96b59aba68cf068                  3.0      F   82000.0
#
#                                   informational_count_completed  \
# 0610b486422d4921ae7d2bf64640c50b                            0.0
# 78afa995795e4d85b5d9ceeca43f5fef                            1.0
# e2127556f4f64592b11af22de27a7932                            0.0
# 2eeac8d8feae4a8cad5a6af0499a211d                            0.0
# aa4862eba776480b8bb9c68455b8c2e1                            1.0
# ...                                                         ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                            1.0
# 2cb4f97358b841b9a9773a7aa05a9d77                            1.0
# 01d26f638c274aa0b965d24cefe3183f                            1.0
# 9dc1421481194dcd9400aec7c9ae6366                            0.0
# e4052622e5ba45a8b96b59aba68cf068                            0.0
#
#                                   informational_count_received  \
# 0610b486422d4921ae7d2bf64640c50b                           1.0
# 78afa995795e4d85b5d9ceeca43f5fef                           1.0
# e2127556f4f64592b11af22de27a7932                           1.0
# 2eeac8d8feae4a8cad5a6af0499a211d                           1.0
# aa4862eba776480b8bb9c68455b8c2e1                           1.0
# ...                                                        ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                           1.0
# 2cb4f97358b841b9a9773a7aa05a9d77                           2.0
# 01d26f638c274aa0b965d24cefe3183f                           2.0
# 9dc1421481194dcd9400aec7c9ae6366                           0.0
# e4052622e5ba45a8b96b59aba68cf068                           1.0
#
#                                   informational_count_viewed  \
# 0610b486422d4921ae7d2bf64640c50b                         0.0
# 78afa995795e4d85b5d9ceeca43f5fef                         1.0
# e2127556f4f64592b11af22de27a7932                         0.0
# 2eeac8d8feae4a8cad5a6af0499a211d                         0.0
# aa4862eba776480b8bb9c68455b8c2e1                         1.0
# ...                                                      ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                         1.0
# 2cb4f97358b841b9a9773a7aa05a9d77                         1.0
# 01d26f638c274aa0b965d24cefe3183f                         1.0
# 9dc1421481194dcd9400aec7c9ae6366                         0.0
# e4052622e5ba45a8b96b59aba68cf068                         0.0
#
#                                   informational_spent_in_offer  \
# 0610b486422d4921ae7d2bf64640c50b                          0.00
# 78afa995795e4d85b5d9ceeca43f5fef                         49.39
# e2127556f4f64592b11af22de27a7932                          0.00
# 2eeac8d8feae4a8cad5a6af0499a211d                          0.00
# aa4862eba776480b8bb9c68455b8c2e1                          0.00
# ...                                                        ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                          0.00
# 2cb4f97358b841b9a9773a7aa05a9d77                          0.00
# 01d26f638c274aa0b965d24cefe3183f                          7.67
# 9dc1421481194dcd9400aec7c9ae6366                          0.00
# e4052622e5ba45a8b96b59aba68cf068                          0.00
#
#                                   informational_sum_reward
# 0610b486422d4921ae7d2bf64640c50b                       0.0
# 78afa995795e4d85b5d9ceeca43f5fef                       0.0
# e2127556f4f64592b11af22de27a7932                       0.0
# 2eeac8d8feae4a8cad5a6af0499a211d                       0.0
# aa4862eba776480b8bb9c68455b8c2e1                       0.0
# ...                                                    ...
# 6d5f3a774f3d4714ab0c092238f3a1d7                       0.0
# 2cb4f97358b841b9a9773a7aa05a9d77                       0.0
# 01d26f638c274aa0b965d24cefe3183f                       0.0
# 9dc1421481194dcd9400aec7c9ae6366                       0.0
# e4052622e5ba45a8b96b59aba68cf068                       0.0
#
# [13573 rows x 20 columns]

# %%
customers.sort_values('bogo_count_completed')
# Out:
#                                   age  amount_spent_total  became_member_on  \
# 523426eccf2848f2a0341527a6b970fe   76               19.54          20180211
# 7997baebfd55418e82320d095834af8d   74               41.78          20180108
# a95968b000c74428a8a9d2fe8b5963f5   43                0.00          20170829
# fe6aa84b089547149a6adfb80a17cb5d   24               13.71          20180605
# 13032878f513409bb503d79069bd8779   22               15.71          20171220
# ...                               ...                 ...               ...
# b0e48cab3d794637b8f9209090989e92   42              268.26          20170806
# 50957b9a771f4e5d9df530c13a1184f1   50              592.43          20150910
# 9e5c4fbb6e784461b2e3e92872ee3e1d   32              242.75          20170730
# 1acb3e87e3304271a3c917cc80a53780   87              143.33          20160514
# 128b2581fc6a4eecb542dd071fd5ea33   77              236.23          20150903
#
#                                   bogo_count_completed  bogo_count_received  \
# 523426eccf2848f2a0341527a6b970fe                   0.0                  1.0
# 7997baebfd55418e82320d095834af8d                   0.0                  0.0
# a95968b000c74428a8a9d2fe8b5963f5                   0.0                  2.0
# fe6aa84b089547149a6adfb80a17cb5d                   0.0                  1.0
# 13032878f513409bb503d79069bd8779                   0.0                  3.0
# ...                                                ...                  ...
# b0e48cab3d794637b8f9209090989e92                   5.0                  5.0
# 50957b9a771f4e5d9df530c13a1184f1                   5.0                  5.0
# 9e5c4fbb6e784461b2e3e92872ee3e1d                   5.0                  5.0
# 1acb3e87e3304271a3c917cc80a53780                   5.0                  6.0
# 128b2581fc6a4eecb542dd071fd5ea33                   5.0                  5.0
#
#                                   bogo_count_viewed  bogo_spent_in_offer  \
# 523426eccf2848f2a0341527a6b970fe                1.0                 0.00
# 7997baebfd55418e82320d095834af8d                0.0                 0.00
# a95968b000c74428a8a9d2fe8b5963f5                2.0                 0.00
# fe6aa84b089547149a6adfb80a17cb5d                0.0                 0.00
# 13032878f513409bb503d79069bd8779                2.0                 0.00
# ...                                             ...                  ...
# b0e48cab3d794637b8f9209090989e92                5.0                98.89
# 50957b9a771f4e5d9df530c13a1184f1                4.0               392.19
# 9e5c4fbb6e784461b2e3e92872ee3e1d                5.0                41.47
# 1acb3e87e3304271a3c917cc80a53780                6.0                59.10
# 128b2581fc6a4eecb542dd071fd5ea33                5.0                58.22
#
#                                   bogo_sum_reward  discount_count_completed  \
# 523426eccf2848f2a0341527a6b970fe              0.0                       0.0
# 7997baebfd55418e82320d095834af8d              0.0                       0.0
# a95968b000c74428a8a9d2fe8b5963f5              0.0                       0.0
# fe6aa84b089547149a6adfb80a17cb5d              0.0                       0.0
# 13032878f513409bb503d79069bd8779              0.0                       0.0
# ...                                           ...                       ...
# b0e48cab3d794637b8f9209090989e92             45.0                       0.0
# 50957b9a771f4e5d9df530c13a1184f1             35.0                       1.0
# 9e5c4fbb6e784461b2e3e92872ee3e1d             40.0                       0.0
# 1acb3e87e3304271a3c917cc80a53780             40.0                       0.0
# 128b2581fc6a4eecb542dd071fd5ea33             35.0                       0.0
#
#                                   discount_count_received  \
# 523426eccf2848f2a0341527a6b970fe                      1.0
# 7997baebfd55418e82320d095834af8d                      1.0
# a95968b000c74428a8a9d2fe8b5963f5                      1.0
# fe6aa84b089547149a6adfb80a17cb5d                      1.0
# 13032878f513409bb503d79069bd8779                      2.0
# ...                                                   ...
# b0e48cab3d794637b8f9209090989e92                      0.0
# 50957b9a771f4e5d9df530c13a1184f1                      1.0
# 9e5c4fbb6e784461b2e3e92872ee3e1d                      1.0
# 1acb3e87e3304271a3c917cc80a53780                      0.0
# 128b2581fc6a4eecb542dd071fd5ea33                      0.0
#
#                                   discount_count_viewed  \
# 523426eccf2848f2a0341527a6b970fe                    1.0
# 7997baebfd55418e82320d095834af8d                    1.0
# a95968b000c74428a8a9d2fe8b5963f5                    1.0
# fe6aa84b089547149a6adfb80a17cb5d                    1.0
# 13032878f513409bb503d79069bd8779                    2.0
# ...                                                 ...
# b0e48cab3d794637b8f9209090989e92                    0.0
# 50957b9a771f4e5d9df530c13a1184f1                    1.0
# 9e5c4fbb6e784461b2e3e92872ee3e1d                    0.0
# 1acb3e87e3304271a3c917cc80a53780                    0.0
# 128b2581fc6a4eecb542dd071fd5ea33                    0.0
#
#                                   discount_spent_in_offer  \
# 523426eccf2848f2a0341527a6b970fe                     0.00
# 7997baebfd55418e82320d095834af8d                     0.00
# a95968b000c74428a8a9d2fe8b5963f5                     0.00
# fe6aa84b089547149a6adfb80a17cb5d                     0.00
# 13032878f513409bb503d79069bd8779                     0.00
# ...                                                   ...
# b0e48cab3d794637b8f9209090989e92                     0.00
# 50957b9a771f4e5d9df530c13a1184f1                    16.72
# 9e5c4fbb6e784461b2e3e92872ee3e1d                     0.00
# 1acb3e87e3304271a3c917cc80a53780                     0.00
# 128b2581fc6a4eecb542dd071fd5ea33                     0.00
#
#                                   discount_sum_reward gender   income  \
# 523426eccf2848f2a0341527a6b970fe                  0.0      M  54000.0
# 7997baebfd55418e82320d095834af8d                  0.0      F  53000.0
# a95968b000c74428a8a9d2fe8b5963f5                  0.0      F  63000.0
# fe6aa84b089547149a6adfb80a17cb5d                  0.0      M  46000.0
# 13032878f513409bb503d79069bd8779                  0.0      M  53000.0
# ...                                               ...    ...      ...
# b0e48cab3d794637b8f9209090989e92                  0.0      M  68000.0
# 50957b9a771f4e5d9df530c13a1184f1                  2.0      F  48000.0
# 9e5c4fbb6e784461b2e3e92872ee3e1d                  0.0      F  47000.0
# 1acb3e87e3304271a3c917cc80a53780                  0.0      F  76000.0
# 128b2581fc6a4eecb542dd071fd5ea33                  0.0      F  59000.0
#
#                                   informational_count_completed  \
# 523426eccf2848f2a0341527a6b970fe                            0.0
# 7997baebfd55418e82320d095834af8d                            1.0
# a95968b000c74428a8a9d2fe8b5963f5                            2.0
# fe6aa84b089547149a6adfb80a17cb5d                            0.0
# 13032878f513409bb503d79069bd8779                            0.0
# ...                                                         ...
# b0e48cab3d794637b8f9209090989e92                            0.0
# 50957b9a771f4e5d9df530c13a1184f1                            0.0
# 9e5c4fbb6e784461b2e3e92872ee3e1d                            0.0
# 1acb3e87e3304271a3c917cc80a53780                            0.0
# 128b2581fc6a4eecb542dd071fd5ea33                            1.0
#
#                                   informational_count_received  \
# 523426eccf2848f2a0341527a6b970fe                           0.0
# 7997baebfd55418e82320d095834af8d                           1.0
# a95968b000c74428a8a9d2fe8b5963f5                           3.0
# fe6aa84b089547149a6adfb80a17cb5d                           1.0
# 13032878f513409bb503d79069bd8779                           0.0
# ...                                                        ...
# b0e48cab3d794637b8f9209090989e92                           0.0
# 50957b9a771f4e5d9df530c13a1184f1                           0.0
# 9e5c4fbb6e784461b2e3e92872ee3e1d                           0.0
# 1acb3e87e3304271a3c917cc80a53780                           0.0
# 128b2581fc6a4eecb542dd071fd5ea33                           1.0
#
#                                   informational_count_viewed  \
# 523426eccf2848f2a0341527a6b970fe                         0.0
# 7997baebfd55418e82320d095834af8d                         1.0
# a95968b000c74428a8a9d2fe8b5963f5                         2.0
# fe6aa84b089547149a6adfb80a17cb5d                         0.0
# 13032878f513409bb503d79069bd8779                         0.0
# ...                                                      ...
# b0e48cab3d794637b8f9209090989e92                         0.0
# 50957b9a771f4e5d9df530c13a1184f1                         0.0
# 9e5c4fbb6e784461b2e3e92872ee3e1d                         0.0
# 1acb3e87e3304271a3c917cc80a53780                         0.0
# 128b2581fc6a4eecb542dd071fd5ea33                         1.0
#
#                                   informational_spent_in_offer  \
# 523426eccf2848f2a0341527a6b970fe                          0.00
# 7997baebfd55418e82320d095834af8d                          0.00
# a95968b000c74428a8a9d2fe8b5963f5                          0.00
# fe6aa84b089547149a6adfb80a17cb5d                          0.00
# 13032878f513409bb503d79069bd8779                          0.00
# ...                                                        ...
# b0e48cab3d794637b8f9209090989e92                          0.00
# 50957b9a771f4e5d9df530c13a1184f1                          0.00
# 9e5c4fbb6e784461b2e3e92872ee3e1d                          0.00
# 1acb3e87e3304271a3c917cc80a53780                          0.00
# 128b2581fc6a4eecb542dd071fd5ea33                         18.88
#
#                                   informational_sum_reward
# 523426eccf2848f2a0341527a6b970fe                       0.0
# 7997baebfd55418e82320d095834af8d                       0.0
# a95968b000c74428a8a9d2fe8b5963f5                       0.0
# fe6aa84b089547149a6adfb80a17cb5d                       0.0
# 13032878f513409bb503d79069bd8779                       0.0
# ...                                                    ...
# b0e48cab3d794637b8f9209090989e92                       0.0
# 50957b9a771f4e5d9df530c13a1184f1                       0.0
# 9e5c4fbb6e784461b2e3e92872ee3e1d                       0.0
# 1acb3e87e3304271a3c917cc80a53780                       0.0
# 128b2581fc6a4eecb542dd071fd5ea33                       0.0
#
# [13573 rows x 20 columns]

# %%
customers.sort_values('informational_count_completed')
# Out:
#                                   age  amount_spent_total  became_member_on  \
# 0610b486422d4921ae7d2bf64640c50b   55               77.01          20170715
# 29f206c56f414159bf31ab8feac7bc66   50              131.91          20161126
# 9a377b76528d4c5c805872b6149fd566   62               52.43          20171113
# 9a909a237a0b42548e3de9a7ab700d60   65              122.58          20171225
# 4c8e591aef3c4b19ab58a85993521061   81              107.91          20160519
# ...                               ...                 ...               ...
# 5d6fe66ee0764083ba82abc7af9f7a97   53               69.53          20160509
# dca5e3cb4b4a4a399933444bc2a1fbd5   68               44.68          20150320
# cf22868e36e748c9ae5a1d8dfea9f249   44              135.94          20180610
# 7bd0d9a569a74eb3949955b4548f34db   69               18.57          20180706
# 14f12efd9aa04c009e9bde68d66509e5   72               98.12          20170616
#
#                                   bogo_count_completed  bogo_count_received  \
# 0610b486422d4921ae7d2bf64640c50b                   1.0                  1.0
# 29f206c56f414159bf31ab8feac7bc66                   2.0                  3.0
# 9a377b76528d4c5c805872b6149fd566                   2.0                  2.0
# 9a909a237a0b42548e3de9a7ab700d60                   2.0                  2.0
# 4c8e591aef3c4b19ab58a85993521061                   2.0                  3.0
# ...                                                ...                  ...
# 5d6fe66ee0764083ba82abc7af9f7a97                   0.0                  1.0
# dca5e3cb4b4a4a399933444bc2a1fbd5                   0.0                  0.0
# cf22868e36e748c9ae5a1d8dfea9f249                   0.0                  0.0
# 7bd0d9a569a74eb3949955b4548f34db                   0.0                  1.0
# 14f12efd9aa04c009e9bde68d66509e5                   0.0                  0.0
#
#                                   bogo_count_viewed  bogo_spent_in_offer  \
# 0610b486422d4921ae7d2bf64640c50b                0.0                 0.00
# 29f206c56f414159bf31ab8feac7bc66                2.0                31.96
# 9a377b76528d4c5c805872b6149fd566                2.0                22.70
# 9a909a237a0b42548e3de9a7ab700d60                1.0                10.08
# 4c8e591aef3c4b19ab58a85993521061                3.0                46.96
# ...                                             ...                  ...
# 5d6fe66ee0764083ba82abc7af9f7a97                1.0                 0.00
# dca5e3cb4b4a4a399933444bc2a1fbd5                0.0                 0.00
# cf22868e36e748c9ae5a1d8dfea9f249                0.0                 0.00
# 7bd0d9a569a74eb3949955b4548f34db                1.0                 0.00
# 14f12efd9aa04c009e9bde68d66509e5                0.0                 0.00
#
#                                   bogo_sum_reward  discount_count_completed  \
# 0610b486422d4921ae7d2bf64640c50b              5.0                       0.0
# 29f206c56f414159bf31ab8feac7bc66             20.0                       2.0
# 9a377b76528d4c5c805872b6149fd566             15.0                       0.0
# 9a909a237a0b42548e3de9a7ab700d60             15.0                       2.0
# 4c8e591aef3c4b19ab58a85993521061             10.0                       0.0
# ...                                           ...                       ...
# 5d6fe66ee0764083ba82abc7af9f7a97              0.0                       0.0
# dca5e3cb4b4a4a399933444bc2a1fbd5              0.0                       0.0
# cf22868e36e748c9ae5a1d8dfea9f249              0.0                       0.0
# 7bd0d9a569a74eb3949955b4548f34db              0.0                       0.0
# 14f12efd9aa04c009e9bde68d66509e5              0.0                       1.0
#
#                                   discount_count_received  \
# 0610b486422d4921ae7d2bf64640c50b                      0.0
# 29f206c56f414159bf31ab8feac7bc66                      2.0
# 9a377b76528d4c5c805872b6149fd566                      1.0
# 9a909a237a0b42548e3de9a7ab700d60                      2.0
# 4c8e591aef3c4b19ab58a85993521061                      1.0
# ...                                                   ...
# 5d6fe66ee0764083ba82abc7af9f7a97                      0.0
# dca5e3cb4b4a4a399933444bc2a1fbd5                      1.0
# cf22868e36e748c9ae5a1d8dfea9f249                      0.0
# 7bd0d9a569a74eb3949955b4548f34db                      1.0
# 14f12efd9aa04c009e9bde68d66509e5                      1.0
#
#                                   discount_count_viewed  \
# 0610b486422d4921ae7d2bf64640c50b                    0.0
# 29f206c56f414159bf31ab8feac7bc66                    2.0
# 9a377b76528d4c5c805872b6149fd566                    1.0
# 9a909a237a0b42548e3de9a7ab700d60                    1.0
# 4c8e591aef3c4b19ab58a85993521061                    1.0
# ...                                                 ...
# 5d6fe66ee0764083ba82abc7af9f7a97                    0.0
# dca5e3cb4b4a4a399933444bc2a1fbd5                    0.0
# cf22868e36e748c9ae5a1d8dfea9f249                    0.0
# 7bd0d9a569a74eb3949955b4548f34db                    0.0
# 14f12efd9aa04c009e9bde68d66509e5                    0.0
#
#                                   discount_spent_in_offer  \
# 0610b486422d4921ae7d2bf64640c50b                     0.00
# 29f206c56f414159bf31ab8feac7bc66                    46.89
# 9a377b76528d4c5c805872b6149fd566                     0.00
# 9a909a237a0b42548e3de9a7ab700d60                     0.00
# 4c8e591aef3c4b19ab58a85993521061                     0.00
# ...                                                   ...
# 5d6fe66ee0764083ba82abc7af9f7a97                     0.00
# dca5e3cb4b4a4a399933444bc2a1fbd5                     0.00
# cf22868e36e748c9ae5a1d8dfea9f249                     0.00
# 7bd0d9a569a74eb3949955b4548f34db                     0.00
# 14f12efd9aa04c009e9bde68d66509e5                     0.00
#
#                                   discount_sum_reward gender    income  \
# 0610b486422d4921ae7d2bf64640c50b                  0.0      F  112000.0
# 29f206c56f414159bf31ab8feac7bc66                  5.0      F   83000.0
# 9a377b76528d4c5c805872b6149fd566                  0.0      F   51000.0
# 9a909a237a0b42548e3de9a7ab700d60                  7.0      F   64000.0
# 4c8e591aef3c4b19ab58a85993521061                  0.0      F   84000.0
# ...                                               ...    ...       ...
# 5d6fe66ee0764083ba82abc7af9f7a97                  0.0      M   58000.0
# dca5e3cb4b4a4a399933444bc2a1fbd5                  0.0      M   51000.0
# cf22868e36e748c9ae5a1d8dfea9f249                  0.0      F   71000.0
# 7bd0d9a569a74eb3949955b4548f34db                  0.0      M   61000.0
# 14f12efd9aa04c009e9bde68d66509e5                  5.0      F  108000.0
#
#                                   informational_count_completed  \
# 0610b486422d4921ae7d2bf64640c50b                            0.0
# 29f206c56f414159bf31ab8feac7bc66                            0.0
# 9a377b76528d4c5c805872b6149fd566                            0.0
# 9a909a237a0b42548e3de9a7ab700d60                            0.0
# 4c8e591aef3c4b19ab58a85993521061                            0.0
# ...                                                         ...
# 5d6fe66ee0764083ba82abc7af9f7a97                            4.0
# dca5e3cb4b4a4a399933444bc2a1fbd5                            4.0
# cf22868e36e748c9ae5a1d8dfea9f249                            4.0
# 7bd0d9a569a74eb3949955b4548f34db                            4.0
# 14f12efd9aa04c009e9bde68d66509e5                            4.0
#
#                                   informational_count_received  \
# 0610b486422d4921ae7d2bf64640c50b                           1.0
# 29f206c56f414159bf31ab8feac7bc66                           1.0
# 9a377b76528d4c5c805872b6149fd566                           0.0
# 9a909a237a0b42548e3de9a7ab700d60                           1.0
# 4c8e591aef3c4b19ab58a85993521061                           0.0
# ...                                                        ...
# 5d6fe66ee0764083ba82abc7af9f7a97                           4.0
# dca5e3cb4b4a4a399933444bc2a1fbd5                           5.0
# cf22868e36e748c9ae5a1d8dfea9f249                           4.0
# 7bd0d9a569a74eb3949955b4548f34db                           4.0
# 14f12efd9aa04c009e9bde68d66509e5                           4.0
#
#                                   informational_count_viewed  \
# 0610b486422d4921ae7d2bf64640c50b                         0.0
# 29f206c56f414159bf31ab8feac7bc66                         0.0
# 9a377b76528d4c5c805872b6149fd566                         0.0
# 9a909a237a0b42548e3de9a7ab700d60                         0.0
# 4c8e591aef3c4b19ab58a85993521061                         0.0
# ...                                                      ...
# 5d6fe66ee0764083ba82abc7af9f7a97                         4.0
# dca5e3cb4b4a4a399933444bc2a1fbd5                         4.0
# cf22868e36e748c9ae5a1d8dfea9f249                         4.0
# 7bd0d9a569a74eb3949955b4548f34db                         4.0
# 14f12efd9aa04c009e9bde68d66509e5                         4.0
#
#                                   informational_spent_in_offer  \
# 0610b486422d4921ae7d2bf64640c50b                          0.00
# 29f206c56f414159bf31ab8feac7bc66                          0.00
# 9a377b76528d4c5c805872b6149fd566                          0.00
# 9a909a237a0b42548e3de9a7ab700d60                          0.00
# 4c8e591aef3c4b19ab58a85993521061                          0.00
# ...                                                        ...
# 5d6fe66ee0764083ba82abc7af9f7a97                         42.42
# dca5e3cb4b4a4a399933444bc2a1fbd5                         17.05
# cf22868e36e748c9ae5a1d8dfea9f249                         76.84
# 7bd0d9a569a74eb3949955b4548f34db                          4.92
# 14f12efd9aa04c009e9bde68d66509e5                          0.00
#
#                                   informational_sum_reward
# 0610b486422d4921ae7d2bf64640c50b                       0.0
# 29f206c56f414159bf31ab8feac7bc66                       0.0
# 9a377b76528d4c5c805872b6149fd566                       0.0
# 9a909a237a0b42548e3de9a7ab700d60                       0.0
# 4c8e591aef3c4b19ab58a85993521061                       0.0
# ...                                                    ...
# 5d6fe66ee0764083ba82abc7af9f7a97                       0.0
# dca5e3cb4b4a4a399933444bc2a1fbd5                       0.0
# cf22868e36e748c9ae5a1d8dfea9f249                       0.0
# 7bd0d9a569a74eb3949955b4548f34db                       0.0
# 14f12efd9aa04c009e9bde68d66509e5                       0.0
#
# [13573 rows x 20 columns]
